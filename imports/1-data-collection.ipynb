# %% [markdown]
# # Sources
#
# Modified from an original project by nik-davis at [github](https://github.com/nik-davis/steam-data-science-project)

# %% [markdown]
# # Steam Data Collection
#
# *This forms part of a larger series of posts for my [blog](http://nik-davis.github.io) on downloading, processing and analysing data from the Steam store. [See all posts here](http://nik-davis.github.io/tag/steam).*

# %%
# Original at
# https://github.com/nik-davis/steam-data-science-project/blob/master/notebooks/1-data-collection.ipynb
#

# %% [markdown]
# ![steam_logo](https://nik-davis.github.io/images/steam_logo_white.jpg)

# %% [markdown]
# The first time I used Steam was with an account I can't remember the name of, playing a game which could well have been [Dark Messiah of Might & Magic](https://store.steampowered.com/app/2100/Dark_Messiah_of_Might__Magic/), on a computer that would easily be blown away by the processing power of my phone today.
#
# It was sometime in 2006, when every game I bought came on a disk in a box that now gathers dust somewhere in my parents' house. Surprisingly my current PC has a disk drive, though I can't remember the last time used it.
#
# In order to play the multiplayer component of the game, annoyingly I had to install a piece of third-party software I had never heard of called Steam, creating the account I have long since lost in the process. Here's what that software probably looked like at the time:

# %% [markdown]
# <p class="source" style="text-align: center"><img src="https://nik-davis.github.io/images/steam_store_2006.jpg" width="700">Source: <a href="https://gfycat.com/@pcgevan">pcgevan</a> via <a href=https://www.pcgamer.com/uk/steam-versions/>PC Gamer</a></p>

# %% [markdown]
# Fast-forward a little over 10 years and the <a href="https://en.wikipedia.org/wiki/Steam_(software)">Steam Store</a> is huge, ubiquitous as the home of PC gaming and distribution. Whilst physical copies still just about feel at home on consoles, the PC market has [long since moved digital](https://www.pcgamer.com/uk/analyst-says-digital-sales-made-up-92-percent-of-pc-game-market-in-2013/). In case you are not familiar, Steam is a digital store for purchasing, downloading and playing video games. It hosts a variety of community features, allows pushing game updates to users automatically, and gathers news stories relevant to each title. It's a bit like [Google's Play Store](https://play.google.com) or [Apple's App Store](https://www.apple.com/uk/ios/app-store/) for phones.
#
# A large part of Steam's success as a platform is due to its use of frequent sales, convenience as a unified digital game library, and the aforementioned shift to digital over physical. Whilst other platforms are emerging and gaining traction, there is likely no better resource for examining gaming over the last decade. With that in mind, if we can construct a dataset from Steam's data, we will have access to a wealth of information about [nearly 30,000 games](https://store.steampowered.com/about/) released since 2003, when Steam first launched.

# %% [markdown]
# ## Project Goals
#
# <!-- PELICAN_BEGIN_SUMMARY -->
#
# The motivation for this project is to download, process and analyse a data set of Steam apps (games) from the Steam store, and gain insights into what makes a game more successful in terms of sales, play-time and ratings. We will imagine that we have been approached by a company hoping to develop and release a new title, using the findings we provide them to inform decisions about how best to manage their budget and hopefully increase the success of their next release.
#
# The first step will be tackling data collection - the actual retrieval of data from Steam's servers and databases. In the future we'll look at cleaning the data, transforming it into a more useful state, then on to data exploration and analysis. Finally we'll summarise our findings in a non-technical report which would be sent to the fictional company in question.
#
# <!-- PELICAN_END_SUMMARY -->
#
# At the end of the data collection and cleaning stages, we'd like to end up with a table or database like this:
#
# name | id | information | owners | price | rating
# --- | --- | --- | --- | --- | ---
# awesome game | 100 | genres, descriptors, variables | 100,000 | £9.99 | 9/10
# generic shooter 4 | 200 | definitely the best shooter | 50,000 | £39.99 | 6/10
# ... | ... | ... | ... | ... | ...
#
# We can then interrogate the data, and investigate whether particular attributes tend to result in more successful games. Metrics like ownership and ratings should help define the success of a title.
#
# ## Data Acquisition
#
# There are a number of ways to get this information. Obviously we could search the web (and especially [kaggle](https://www.kaggle.com/datasets)) for existing datasets, however to avoid letting someone else get away with all that hard work (and mainly for the purposes of learning) we'll be acquiring all the data ourselves from scratch.
#
# Often when generating data the best place to start is to check for APIs. Fortunately Valve (the company behind Steam) make one available at https://partner.steamgames.com/. An [API](https://en.wikipedia.org/wiki/Application_programming_interface) such as this allows anyone to interface with data on a website in a controlled way, usually providing a host of useful features to the end-user. Typically an API is a great way for developers to allow access to databases and information on a server. Unfortunately this documentation doesn't include all access points, but others have documented this for us. [This](https://wiki.teamfortress.com/wiki/User:RJackson/StorefrontAPI) documentation of the StorefrontAPI will be particularly useful.
#
# We'll be able to get good information about the details of each game from the Steam API, however we're still missing information about popularity and sales. Luckily we can easily get this data from another website, SteamSpy.
#
# [SteamSpy](https://steamspy.com/about) is a Steam stats-gathering service and crucially has data easily available through its own API (documentation [here](https://steamspy.com/api.php)). It provides a number of useful metrics including an estimation for total owners of each game.
#
# We'll be retrieving data from both APIs and combining them to form our dataset. For the purposes of this project, we'll be performing as little data cleaning as possible at this stage, providing 'dirty' data for data cleaning, the next step in this project.
#
# ## Section outline:
#
# - Create an app list from SteamSpy API using 'all' request
# - Retrieve individual app data from Steam API, by iterating through app list
# - Retrieve individual app data from SteamSpy API, by iterating through app list
# - Export app list, Steam data and SteamSpy data to csv files
#
# ## API references:
#
# - https://partner.steamgames.com/doc/webapi
# - https://wiki.teamfortress.com/wiki/User:RJackson/StorefrontAPI
# - https://steamapi.xpaw.me/#
# - https://steamspy.com/api.php
#
#
# ## Import Libraries
#
# We begin by importing the libraries we will be using. We start with [standard library imports](https://docs.python.org/3/library/), or those available by default in Python, then import the third-party packages. We'll be using [requests](https://2.python-requests.org/en/master/) to handle interacting with the APIs, then the popular [pandas](http://pandas.pydata.org/pandas-docs/stable/) and [numpy](https://docs.scipy.org/doc/numpy/index.html) libraries for handling the downloaded data.

# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time

# third-party imports
import numpy as np
import pandas as pd
import requests

# customisations - ensure tables show all columns
pd.set_option("max_columns", 100)

# %% [markdown]
# Next, we define a general, all-purpose function to process get requests from an API, supplied through a URL parameter. A dictionary of parameters can be supplied which is passed into the get request automatically, depending on the requirements of the API.
#
# Rather than simply returning the response, we handle a couple of scenarios to help automation. Occasionally we encounter an SSL Error, in which case we simply wait a few seconds then try again (by recursively calling the function). When this happens, and generally throughout this project, we provide quite verbose feedback to show when these errors are encountered and how they are handled.
#
# Sometimes there is no response when a request is made (returns None). This usually happens when too many requests are made in a short period of time, and the polling limit has been reached. We try to avoid this by pausing briefly between requests, as we'll see later, but in case we breach the polling limit we wait 10 seconds then try again.
#
# Handling these errors in this way ensures that our function almost always returns the desired response, which we return in json format to make processing easier.

# %%
def get_request(url, parameters=None, attempt = 0):
    """Return json-formatted response of a get request using optional parameters.
    
    Parameters
    ----------
    url : string
    parameters : {'parameter': 'value'}
        parameters to pass as part of get request
    
    Returns
    -------
    json_data
        json-formatted response (dict-like)
    """
    try:
        response = requests.get(url=url, params=parameters)
    except SSLError as s:
        print('SSL Error:', s)
        
        for i in range(5, 0, -1):
            print('\rWaiting... ({})'.format(i), end='')
            time.sleep(1)
        print('\rRetrying.' + ' '*10)
        if attempt > 100:
            return None
        # recusively try again
        return get_request(url, parameters, attempt+1)
    
    if response:
        return response
    else:
        # response is none usually means too many requests. Wait and try again 
        if attempt > 5:
            return None
        else:
            print('No response, waiting 30 seconds...')
            time.sleep(30)
        print(f'Retrying. Attempt # {attempt+1}')
        if attempt > 10:
            return None
        # recusively try again
        return get_request(url, parameters, attempt+1)

# %% [markdown]
# ## Generate List of App IDs
#
# Every app on the steam store has a unique app ID. Whilst different apps can have the same name, they can't have the same ID. This will be very useful to us for identifying apps and eventually merging our tables of data.
#
# Before we get to that, we need to generate a list of app ids which we can use to build our data sets. It's possible to generate one from the Steam API, however this has over 70,000 entries, many of which are demos and videos with no way to tell them apart. Instead, SteamSpy provides an 'all' request, supplying some information about the apps they track. It doesn't supply all information about each app, so we still need to request this information individually, but it provides a good starting point.
#
# Because many of the return fields are strings containing commas and other punctuation, it is easiest to read the response into a pandas dataframe, and export the required appid and name fields to a csv. We could keep only the appid column as a list or pandas series, but it may be useful to keep the app name at this stage.

# %%
url = "https://steamspy.com/api.php"
i = 0
json_data = {}
while (True):
    parameters = {"request": "all", "page" : i}
    # request 'all' from steam spy and parse into dataframe
    r = get_request(url, parameters=parameters)
    if (r == None or r.status_code != 200):
        break
    json_data.update(r.json())
    i = i+1
    print(f'Page {i} loaded')

steam_spy_all = pd.DataFrame.from_dict(json_data, orient='index')

# generate sorted app_list from steamspy data
app_list = steam_spy_all[['appid', 'name']].sort_values('appid').reset_index(drop=True)

# export disabled to keep consistency across download sessions
app_list.to_csv('../data/download/app_list.csv', index=False)

# instead read from stored csv
# app_list = pd.read_csv('../data/download/app_list.csv')

# display first few rows
app_list.shape
# Out:
# Page 1 loaded
# Page 2 loaded
# Page 3 loaded
# Page 4 loaded
# Page 5 loaded
# Page 6 loaded
# Page 7 loaded
# Page 8 loaded
# Page 9 loaded
# Page 10 loaded
# Page 11 loaded
# Page 12 loaded
# Page 13 loaded
# Page 14 loaded
# Page 15 loaded
# Page 16 loaded
# Page 17 loaded
# Page 18 loaded
# Page 19 loaded
# Page 20 loaded
# Page 21 loaded
# Page 22 loaded
# Page 23 loaded
# Page 24 loaded
# Page 25 loaded
# Page 26 loaded
# Page 27 loaded
# Page 28 loaded
# Page 29 loaded
# Page 30 loaded
# Page 31 loaded
# Page 32 loaded
# Page 33 loaded
# Page 34 loaded
# Page 35 loaded
# Page 36 loaded
# Page 37 loaded
# Page 38 loaded
# Page 39 loaded
# Page 40 loaded
# Page 41 loaded
# Page 42 loaded
# Page 43 loaded
# Page 44 loaded
# Page 45 loaded
# Page 46 loaded
# Page 47 loaded
# Page 48 loaded
# Page 49 loaded
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# No response, waiting 10 seconds...
# Retrying. Attempt # 6
# (47397, 2)

# %% [markdown]
# ## Define Download Logic
#
# Now we have the `app_list` dataframe, we can iterate over the app IDs and request individual app data from the servers. Here we set out our logic to retrieve and process this information, then finally store the data as a csv file.
#
# Because it takes a long time to retrieve the data, it would be dangerous to attempt it all in one go as any errors or connection time-outs could cause the loss of all our data. For this reason we define a function to download and process the requests in batches, appending each batch to an external file and keeping track of the highest index written in a separate file.
#
# This not only provides security, allowing us to easily restart the process if an error is encountered, but also means we can complete the download across multiple sessions.
#
# Again, we provide verbose output for rows exported, batches complete, time taken and estimated time remaining.

# %%
def get_app_data(start, stop, parser, pause):
    """Return list of app data generated from parser.
    
    parser : function to handle request
    """
    app_data = []
    
    # iterate through each row of app_list, confined by start and stop
    for index, row in app_list[start:stop].iterrows():
        print('Current index: {}'.format(index), end='\r')
        
        appid = row['appid']
        name = row['name']

        # retrive app data for a row, handled by supplied parser, and append to list
        data = parser(appid, name)
        app_data.append(data)

        time.sleep(pause) # prevent overloading api with requests
    
    return app_data


def process_batches(parser, app_list, download_path, data_filename, index_filename,
                    columns, begin=0, end=-1, batchsize=100, pause=1):
    """Process app data in batches, writing directly to file.
    
    parser : custom function to format request
    app_list : dataframe of appid and name
    download_path : path to store data
    data_filename : filename to save app data
    index_filename : filename to store highest index written
    columns : column names for file
    
    Keyword arguments:
    
    begin : starting index (get from index_filename, default 0)
    end : index to finish (defaults to end of app_list)
    batchsize : number of apps to write in each batch (default 100)
    pause : time to wait after each api request (defualt 1)
    
    returns: none
    """
    print('Starting at index {}:\n'.format(begin))
    
    # by default, process all apps in app_list
    if end == -1:
        end = len(app_list) + 1
    
    # generate array of batch begin and end points
    batches = np.arange(begin, end, batchsize)
    batches = np.append(batches, end)
    
    apps_written = 0
    batch_times = []
    
    for i in range(len(batches) - 1):
        start_time = time.time()
        
        start = batches[i]
        stop = batches[i+1]
        
        app_data = get_app_data(start, stop, parser, pause)
        
        rel_path = os.path.join(download_path, data_filename)
        
        # writing app data to file
        with open(rel_path, 'a', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=columns, extrasaction='ignore')
            
            for j in range(3,0,-1):
                print("\rAbout to write data, don't stop script! ({})".format(j), end='')
                time.sleep(0.5)
            
            writer.writerows(app_data)
            print('\rExported lines {}-{} to {}.'.format(start, stop-1, data_filename), end=' ')
            
        apps_written += len(app_data)
        
        idx_path = os.path.join(download_path, index_filename)
        
        # writing last index to file
        with open(idx_path, 'w') as f:
            index = stop
            print(index, file=f)
            
        # logging time taken
        end_time = time.time()
        time_taken = end_time - start_time
        
        batch_times.append(time_taken)
        mean_time = statistics.mean(batch_times)
        
        est_remaining = (len(batches) - i - 2) * mean_time
        
        remaining_td = dt.timedelta(seconds=round(est_remaining))
        time_td = dt.timedelta(seconds=round(time_taken))
        mean_td = dt.timedelta(seconds=round(mean_time))
        
        print('Batch {} time: {} (avg: {}, remaining: {})'.format(i, time_td, mean_td, remaining_td))
            
    print('\nProcessing batches complete. {} apps written'.format(apps_written))

# %% [markdown]
# Next we define some functions to handle and prepare the external files.
#
# We use `reset_index` for testing and demonstration, allowing us to easily reset the index in the stored file to 0, effectively restarting the entire download process.
#
# We define `get_index` to retrieve the index from file, maintaining persistence across sessions. Every time a batch of information (app data) is written to file, we write the highest index within `app_data` that was retrieved. As stated, this is partially for security, ensuring that if there is an error during the download we can read the index from file and continue from the end of the last successful batch. Keeping track of the index also allows us to pause the download, continuing at a later time.
#
# Finally, the `prepare_data_file` function readies the csv for storing the data. If the index we retrieved is 0, it means we are either starting for the first time or starting over. In either case, we want a blank csv file with only the header row to begin writing to, se we wipe the file (by opening in write mode) and write the header. Conversely, if the index is anything other than 0, it means we already have downloaded information, and can leave the csv file alone.

# %%
def reset_index(download_path, index_filename):
    """Reset index in file to 0."""
    rel_path = os.path.join(download_path, index_filename)
    
    with open(rel_path, 'w') as f:
        print(0, file=f)
        

def get_index(download_path, index_filename):
    """Retrieve index from file, returning 0 if file not found."""
    try:
        rel_path = os.path.join(download_path, index_filename)

        with open(rel_path, 'r') as f:
            index = int(f.readline())
    
    except FileNotFoundError:
        index = 0
        
    return index


def prepare_data_file(download_path, filename, index, columns):
    """Create file and write headers if index is 0."""
    if index == 0:
        rel_path = os.path.join(download_path, filename)

        with open(rel_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

# %% [markdown]
# ## Download Steam Data
#
# Now we are ready to start downloading data and writing to file. We define our logic particular to handling the steam API - in fact if no data is returned we return just the name and appid - then begin setting some parameters. We define the files we will write our data and index to, and the columns for the csv file. The API doesn't return every column for every app, so it is best to explicitly set these.
#
# Next we run our functions to set up the files, and make a call to `process_batches` to begin the process. Some additional parameters have been added for demonstration, to constrain the download to just a few rows and smaller batches. Removing these would allow the entire download process to be repeated.

# %%
def parse_steam_request(appid, name):
    """Unique parser to handle data from Steam Store API.
    
    Returns : json formatted data (dict-like)
    """
    url = "http://store.steampowered.com/api/appdetails/"
    parameters = {"appids": appid}
    r = get_request(url, parameters=parameters)
    if r == None:
        return {'name': name, 'steam_appid': appid}
    json_data = r.json()
    json_app_data = json_data[str(appid)]
    
    if json_app_data['success']:
        data = json_app_data['data']
    else:
        data = {'name': name, 'steam_appid': appid}
        
    return data


# Set file parameters
download_path = '../data/download'
steam_app_data = 'steam_app_data.csv'
steam_index = 'steam_index.txt'

steam_columns = [
    'type', 'name', 'steam_appid', 'required_age', 'is_free', 'controller_support',
    'dlc', 'detailed_description', 'about_the_game', 'short_description', 'fullgame',
    'supported_languages', 'header_image', 'website', 'pc_requirements', 'mac_requirements',
    'linux_requirements', 'legal_notice', 'drm_notice', 'ext_user_account_notice',
    'developers', 'publishers', 'demos', 'price_overview', 'packages', 'package_groups',
    'platforms', 'metacritic', 'reviews', 'categories', 'genres', 'screenshots',
    'movies', 'recommendations', 'achievements', 'release_date', 'support_info',
    'background', 'content_descriptors'
]

# Overwrites last index for demonstration (would usually store highest index so can continue across sessions)
reset_index(download_path, steam_index)

# Retrieve last index downloaded from file
index = get_index(download_path, steam_index)

# Wipe or create data file and write headers if index is 0
prepare_data_file(download_path, steam_app_data, index, steam_columns)

# Set end and chunksize for demonstration - remove to run through entire app list
process_batches(
    parser=parse_steam_request,
    app_list=app_list,
    download_path=download_path,
    data_filename=steam_app_data,
    index_filename=steam_index,
    columns=steam_columns,
    begin=index
)
# Out:
# Starting at index 0:
#
# Exported lines 0-99 to steam_app_data.csv. Batch 0 time: 0:02:06 (avg: 0:02:06, remaining: 16:37:04)
# Exported lines 100-199 to steam_app_data.csv. Batch 1 time: 0:02:06 (avg: 0:02:06, remaining: 16:33:49)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 200-299 to steam_app_data.csv. Batch 2 time: 0:02:58 (avg: 0:02:24, remaining: 18:47:23)
# Exported lines 300-399 to steam_app_data.csv. Batch 3 time: 0:02:06 (avg: 0:02:19, remaining: 18:10:50)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 400-499 to steam_app_data.csv. Batch 4 time: 0:02:58 (avg: 0:02:27, remaining: 19:08:25)
# Exported lines 500-599 to steam_app_data.csv. Batch 5 time: 0:02:08 (avg: 0:02:24, remaining: 18:41:32)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 600-699 to steam_app_data.csv. Batch 6 time: 0:02:59 (avg: 0:02:29, remaining: 19:18:14)
# Exported lines 700-799 to steam_app_data.csv. Batch 7 time: 0:02:07 (avg: 0:02:26, remaining: 18:54:35)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 800-899 to steam_app_data.csv. Batch 8 time: 0:02:57 (avg: 0:02:30, remaining: 19:18:58)
# Exported lines 900-999 to steam_app_data.csv. Batch 9 time: 0:02:08 (avg: 0:02:27, remaining: 18:59:44)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 1000-1099 to steam_app_data.csv. Batch 10 time: 0:02:58 (avg: 0:02:30, remaining: 19:18:42)
# Exported lines 1100-1199 to steam_app_data.csv. Batch 11 time: 0:02:08 (avg: 0:02:28, remaining: 19:01:40)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 1200-1299 to steam_app_data.csv. Batch 12 time: 0:02:58 (avg: 0:02:31, remaining: 19:16:48)
# Exported lines 1300-1399 to steam_app_data.csv. Batch 13 time: 0:02:07 (avg: 0:02:29, remaining: 19:01:26)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 1400-1499 to steam_app_data.csv. Batch 14 time: 0:03:00 (avg: 0:02:31, remaining: 19:14:58)
# Exported lines 1500-1599 to steam_app_data.csv. Batch 15 time: 0:02:08 (avg: 0:02:30, remaining: 19:01:25)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 1600-1699 to steam_app_data.csv. Batch 16 time: 0:02:58 (avg: 0:02:31, remaining: 19:11:37)
# Exported lines 1700-1799 to steam_app_data.csv. Batch 17 time: 0:02:08 (avg: 0:02:30, remaining: 18:59:31)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# Exported lines 1800-1899 to steam_app_data.csv. Batch 18 time: 0:02:51 (avg: 0:02:31, remaining: 19:05:15)
# Exported lines 1900-1999 to steam_app_data.csv. Batch 19 time: 0:02:09 (avg: 0:02:30, remaining: 18:54:18)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 2000-2099 to steam_app_data.csv. Batch 20 time: 0:03:00 (avg: 0:02:31, remaining: 19:02:43)
# Exported lines 2100-2199 to steam_app_data.csv. Batch 21 time: 0:02:09 (avg: 0:02:30, remaining: 18:52:42)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# Exported lines 2200-2299 to steam_app_data.csv. Batch 22 time: 0:02:49 (avg: 0:02:31, remaining: 18:56:21)
# Exported lines 2300-2399 to steam_app_data.csv. Batch 23 time: 0:02:08 (avg: 0:02:30, remaining: 18:46:40)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# Exported lines 2400-2499 to steam_app_data.csv. Batch 24 time: 0:02:52 (avg: 0:02:31, remaining: 18:50:40)
# Exported lines 2500-2599 to steam_app_data.csv. Batch 25 time: 0:02:08 (avg: 0:02:30, remaining: 18:41:35)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 2600-2699 to steam_app_data.csv. Batch 26 time: 0:03:00 (avg: 0:02:31, remaining: 18:47:11)
# Exported lines 2700-2799 to steam_app_data.csv. Batch 27 time: 0:02:08 (avg: 0:02:30, remaining: 18:38:36)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 2800-2899 to steam_app_data.csv. Batch 28 time: 0:03:00 (avg: 0:02:31, remaining: 18:43:35)
# Exported lines 2900-2999 to steam_app_data.csv. Batch 29 time: 0:02:08 (avg: 0:02:31, remaining: 18:35:11)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 3000-3099 to steam_app_data.csv. Batch 30 time: 0:02:59 (avg: 0:02:32, remaining: 18:39:20)
# Exported lines 3100-3199 to steam_app_data.csv. Batch 31 time: 0:02:08 (avg: 0:02:31, remaining: 18:31:24)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 3200-3299 to steam_app_data.csv. Batch 32 time: 0:02:59 (avg: 0:02:32, remaining: 18:35:12)
# Exported lines 3300-3399 to steam_app_data.csv. Batch 33 time: 0:02:08 (avg: 0:02:31, remaining: 18:27:37)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 3400-3499 to steam_app_data.csv. Batch 34 time: 0:03:00 (avg: 0:02:32, remaining: 18:31:07)
# Exported lines 3500-3599 to steam_app_data.csv. Batch 35 time: 0:02:08 (avg: 0:02:31, remaining: 18:23:39)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 3600-3699 to steam_app_data.csv. Batch 36 time: 0:02:59 (avg: 0:02:32, remaining: 18:26:34)
# Exported lines 3700-3799 to steam_app_data.csv. Batch 37 time: 0:02:07 (avg: 0:02:31, remaining: 18:19:21)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 3800-3899 to steam_app_data.csv. Batch 38 time: 0:03:01 (avg: 0:02:32, remaining: 18:22:18)
# Exported lines 3900-3999 to steam_app_data.csv. Batch 39 time: 0:02:08 (avg: 0:02:31, remaining: 18:15:28)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 4000-4099 to steam_app_data.csv. Batch 40 time: 0:02:59 (avg: 0:02:32, remaining: 18:17:50)
# Exported lines 4100-4199 to steam_app_data.csv. Batch 41 time: 0:02:08 (avg: 0:02:32, remaining: 18:11:14)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 4200-4299 to steam_app_data.csv. Batch 42 time: 0:02:58 (avg: 0:02:32, remaining: 18:13:10)
# Exported lines 4300-4399 to steam_app_data.csv. Batch 43 time: 0:02:08 (avg: 0:02:32, remaining: 18:06:42)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 4400-4499 to steam_app_data.csv. Batch 44 time: 0:02:58 (avg: 0:02:32, remaining: 18:08:26)
# Exported lines 4500-4599 to steam_app_data.csv. Batch 45 time: 0:02:07 (avg: 0:02:32, remaining: 18:02:00)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 4600-4699 to steam_app_data.csv. Batch 46 time: 0:02:59 (avg: 0:02:32, remaining: 18:03:37)
# Exported lines 4700-4799 to steam_app_data.csv. Batch 47 time: 0:02:07 (avg: 0:02:32, remaining: 17:57:22)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 4800-4899 to steam_app_data.csv. Batch 48 time: 0:02:58 (avg: 0:02:32, remaining: 17:58:42)
# Exported lines 4900-4999 to steam_app_data.csv. Batch 49 time: 0:02:08 (avg: 0:02:32, remaining: 17:52:41)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 5000-5099 to steam_app_data.csv. Batch 50 time: 0:02:59 (avg: 0:02:32, remaining: 17:53:52)
# Exported lines 5100-5199 to steam_app_data.csv. Batch 51 time: 0:02:08 (avg: 0:02:32, remaining: 17:47:59)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 5200-5299 to steam_app_data.csv. Batch 52 time: 0:02:58 (avg: 0:02:32, remaining: 17:48:55)
# Exported lines 5300-5399 to steam_app_data.csv. Batch 53 time: 0:02:07 (avg: 0:02:32, remaining: 17:43:08)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 5400-5499 to steam_app_data.csv. Batch 54 time: 0:02:59 (avg: 0:02:32, remaining: 17:44:02)
# Exported lines 5500-5599 to steam_app_data.csv. Batch 55 time: 0:02:07 (avg: 0:02:32, remaining: 17:38:23)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 5600-5699 to steam_app_data.csv. Batch 56 time: 0:02:58 (avg: 0:02:32, remaining: 17:39:01)
# Exported lines 5700-5799 to steam_app_data.csv. Batch 57 time: 0:02:07 (avg: 0:02:32, remaining: 17:33:30)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 5800-5899 to steam_app_data.csv. Batch 58 time: 0:02:59 (avg: 0:02:32, remaining: 17:34:07)
# Exported lines 5900-5999 to steam_app_data.csv. Batch 59 time: 0:02:07 (avg: 0:02:32, remaining: 17:28:41)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 6000-6099 to steam_app_data.csv. Batch 60 time: 0:02:58 (avg: 0:02:32, remaining: 17:29:08)
# Exported lines 6100-6199 to steam_app_data.csv. Batch 61 time: 0:02:08 (avg: 0:02:32, remaining: 17:23:54)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 6200-6299 to steam_app_data.csv. Batch 62 time: 0:02:59 (avg: 0:02:32, remaining: 17:24:15)
# Exported lines 6300-6399 to steam_app_data.csv. Batch 63 time: 0:02:07 (avg: 0:02:32, remaining: 17:18:59)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 6400-6499 to steam_app_data.csv. Batch 64 time: 0:02:58 (avg: 0:02:32, remaining: 17:19:13)
# Exported lines 6500-6599 to steam_app_data.csv. Batch 65 time: 0:02:08 (avg: 0:02:32, remaining: 17:14:07)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 6600-6699 to steam_app_data.csv. Batch 66 time: 0:03:00 (avg: 0:02:32, remaining: 17:14:22)
# Exported lines 6700-6799 to steam_app_data.csv. Batch 67 time: 0:02:07 (avg: 0:02:32, remaining: 17:09:18)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 6800-6899 to steam_app_data.csv. Batch 68 time: 0:02:58 (avg: 0:02:32, remaining: 17:09:16)
# Exported lines 6900-6999 to steam_app_data.csv. Batch 69 time: 0:02:07 (avg: 0:02:32, remaining: 17:04:19)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 7000-7099 to steam_app_data.csv. Batch 70 time: 0:02:58 (avg: 0:02:32, remaining: 17:04:13)
# Exported lines 7100-7199 to steam_app_data.csv. Batch 71 time: 0:02:08 (avg: 0:02:32, remaining: 16:59:26)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 7200-7299 to steam_app_data.csv. Batch 72 time: 0:02:58 (avg: 0:02:33, remaining: 16:59:14)
# Exported lines 7300-7399 to steam_app_data.csv. Batch 73 time: 0:02:07 (avg: 0:02:32, remaining: 16:54:26)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 7400-7499 to steam_app_data.csv. Batch 74 time: 0:02:58 (avg: 0:02:33, remaining: 16:54:13)
# Exported lines 7500-7599 to steam_app_data.csv. Batch 75 time: 0:02:08 (avg: 0:02:32, remaining: 16:49:30)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 7600-7699 to steam_app_data.csv. Batch 76 time: 0:02:58 (avg: 0:02:33, remaining: 16:49:12)
# Exported lines 7700-7799 to steam_app_data.csv. Batch 77 time: 0:02:07 (avg: 0:02:32, remaining: 16:44:28)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 7800-7899 to steam_app_data.csv. Batch 78 time: 0:02:58 (avg: 0:02:33, remaining: 16:44:03)
# Exported lines 7900-7999 to steam_app_data.csv. Batch 79 time: 0:02:08 (avg: 0:02:32, remaining: 16:39:27)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 8000-8099 to steam_app_data.csv. Batch 80 time: 0:02:58 (avg: 0:02:33, remaining: 16:39:02)
# Exported lines 8100-8199 to steam_app_data.csv. Batch 81 time: 0:02:08 (avg: 0:02:32, remaining: 16:34:34)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 8200-8299 to steam_app_data.csv. Batch 82 time: 0:02:58 (avg: 0:02:33, remaining: 16:34:01)
# Exported lines 8300-8399 to steam_app_data.csv. Batch 83 time: 0:02:08 (avg: 0:02:32, remaining: 16:29:33)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 8400-8499 to steam_app_data.csv. Batch 84 time: 0:02:58 (avg: 0:02:33, remaining: 16:29:00)
# Exported lines 8500-8599 to steam_app_data.csv. Batch 85 time: 0:02:07 (avg: 0:02:32, remaining: 16:24:31)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 8600-8699 to steam_app_data.csv. Batch 86 time: 0:02:58 (avg: 0:02:33, remaining: 16:23:53)
# Exported lines 8700-8799 to steam_app_data.csv. Batch 87 time: 0:02:07 (avg: 0:02:32, remaining: 16:19:27)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 8800-8899 to steam_app_data.csv. Batch 88 time: 0:02:59 (avg: 0:02:33, remaining: 16:18:48)
# Exported lines 8900-8999 to steam_app_data.csv. Batch 89 time: 0:02:06 (avg: 0:02:32, remaining: 16:14:24)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 9000-9099 to steam_app_data.csv. Batch 90 time: 0:02:58 (avg: 0:02:33, remaining: 16:13:41)
# Exported lines 9100-9199 to steam_app_data.csv. Batch 91 time: 0:02:07 (avg: 0:02:32, remaining: 16:09:21)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 9200-9299 to steam_app_data.csv. Batch 92 time: 0:02:58 (avg: 0:02:33, remaining: 16:08:35)
# Exported lines 9300-9399 to steam_app_data.csv. Batch 93 time: 0:02:07 (avg: 0:02:32, remaining: 16:04:20)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 9400-9499 to steam_app_data.csv. Batch 94 time: 0:02:59 (avg: 0:02:33, remaining: 16:03:35)
# Exported lines 9500-9599 to steam_app_data.csv. Batch 95 time: 0:02:07 (avg: 0:02:32, remaining: 15:59:23)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 9600-9699 to steam_app_data.csv. Batch 96 time: 0:02:59 (avg: 0:02:33, remaining: 15:58:33)
# Exported lines 9700-9799 to steam_app_data.csv. Batch 97 time: 0:02:07 (avg: 0:02:32, remaining: 15:54:24)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 9800-9899 to steam_app_data.csv. Batch 98 time: 0:02:59 (avg: 0:02:33, remaining: 15:53:32)
# Exported lines 9900-9999 to steam_app_data.csv. Batch 99 time: 0:02:07 (avg: 0:02:32, remaining: 15:49:25)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 10000-10099 to steam_app_data.csv. Batch 100 time: 0:02:59 (avg: 0:02:33, remaining: 15:48:30)
# Exported lines 10100-10199 to steam_app_data.csv. Batch 101 time: 0:02:07 (avg: 0:02:32, remaining: 15:44:25)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 10200-10299 to steam_app_data.csv. Batch 102 time: 0:02:58 (avg: 0:02:33, remaining: 15:43:25)
# Exported lines 10300-10399 to steam_app_data.csv. Batch 103 time: 0:02:07 (avg: 0:02:32, remaining: 15:39:22)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 10400-10499 to steam_app_data.csv. Batch 104 time: 0:02:58 (avg: 0:02:33, remaining: 15:38:19)
# Exported lines 10500-10599 to steam_app_data.csv. Batch 105 time: 0:02:07 (avg: 0:02:32, remaining: 15:34:16)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 10600-10699 to steam_app_data.csv. Batch 106 time: 0:02:58 (avg: 0:02:33, remaining: 15:33:12)
# Exported lines 10700-10799 to steam_app_data.csv. Batch 107 time: 0:02:07 (avg: 0:02:32, remaining: 15:29:13)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 10800-10899 to steam_app_data.csv. Batch 108 time: 0:02:58 (avg: 0:02:33, remaining: 15:28:06)
# Exported lines 10900-10999 to steam_app_data.csv. Batch 109 time: 0:02:07 (avg: 0:02:32, remaining: 15:24:08)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 11000-11099 to steam_app_data.csv. Batch 110 time: 0:02:58 (avg: 0:02:33, remaining: 15:22:58)
# Exported lines 11100-11199 to steam_app_data.csv. Batch 111 time: 0:02:07 (avg: 0:02:32, remaining: 15:19:03)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 11200-11299 to steam_app_data.csv. Batch 112 time: 0:02:57 (avg: 0:02:33, remaining: 15:17:49)
# Exported lines 11300-11399 to steam_app_data.csv. Batch 113 time: 0:02:07 (avg: 0:02:32, remaining: 15:13:54)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 11400-11499 to steam_app_data.csv. Batch 114 time: 0:02:57 (avg: 0:02:33, remaining: 15:12:38)
# Exported lines 11500-11599 to steam_app_data.csv. Batch 115 time: 0:02:07 (avg: 0:02:32, remaining: 15:08:48)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 11600-11699 to steam_app_data.csv. Batch 116 time: 0:02:57 (avg: 0:02:33, remaining: 15:07:31)
# Exported lines 11700-11799 to steam_app_data.csv. Batch 117 time: 0:02:07 (avg: 0:02:32, remaining: 15:03:40)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 11800-11899 to steam_app_data.csv. Batch 118 time: 0:02:58 (avg: 0:02:33, remaining: 15:02:24)
# Exported lines 11900-11999 to steam_app_data.csv. Batch 119 time: 0:02:07 (avg: 0:02:32, remaining: 14:58:35)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 12000-12099 to steam_app_data.csv. Batch 120 time: 0:02:58 (avg: 0:02:33, remaining: 14:57:16)
# Exported lines 12100-12199 to steam_app_data.csv. Batch 121 time: 0:02:06 (avg: 0:02:32, remaining: 14:53:28)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 12200-12299 to steam_app_data.csv. Batch 122 time: 0:02:57 (avg: 0:02:32, remaining: 14:52:07)
# Exported lines 12300-12399 to steam_app_data.csv. Batch 123 time: 0:02:06 (avg: 0:02:32, remaining: 14:48:20)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 12400-12499 to steam_app_data.csv. Batch 124 time: 0:02:57 (avg: 0:02:32, remaining: 14:46:56)
# Exported lines 12500-12599 to steam_app_data.csv. Batch 125 time: 0:02:06 (avg: 0:02:32, remaining: 14:43:12)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 12600-12699 to steam_app_data.csv. Batch 126 time: 0:02:58 (avg: 0:02:32, remaining: 14:41:49)
# Exported lines 12700-12799 to steam_app_data.csv. Batch 127 time: 0:02:06 (avg: 0:02:32, remaining: 14:38:06)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 12800-12899 to steam_app_data.csv. Batch 128 time: 0:02:57 (avg: 0:02:32, remaining: 14:36:41)
# Exported lines 12900-12999 to steam_app_data.csv. Batch 129 time: 0:02:07 (avg: 0:02:32, remaining: 14:32:59)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 13000-13099 to steam_app_data.csv. Batch 130 time: 0:02:58 (avg: 0:02:32, remaining: 14:31:35)
# Exported lines 13100-13199 to steam_app_data.csv. Batch 131 time: 0:02:06 (avg: 0:02:32, remaining: 14:27:55)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 13200-13299 to steam_app_data.csv. Batch 132 time: 0:02:58 (avg: 0:02:32, remaining: 14:26:28)
# Exported lines 13300-13399 to steam_app_data.csv. Batch 133 time: 0:02:07 (avg: 0:02:32, remaining: 14:22:50)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 13400-13499 to steam_app_data.csv. Batch 134 time: 0:02:58 (avg: 0:02:32, remaining: 14:21:22)
# Exported lines 13500-13599 to steam_app_data.csv. Batch 135 time: 0:02:07 (avg: 0:02:32, remaining: 14:17:47)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# Exported lines 13600-13699 to steam_app_data.csv. Batch 136 time: 0:02:50 (avg: 0:02:32, remaining: 14:15:58)
# Exported lines 13700-13799 to steam_app_data.csv. Batch 137 time: 0:02:08 (avg: 0:02:32, remaining: 14:12:26)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 13800-13899 to steam_app_data.csv. Batch 138 time: 0:02:59 (avg: 0:02:32, remaining: 14:10:58)
# Exported lines 13900-13999 to steam_app_data.csv. Batch 139 time: 0:02:07 (avg: 0:02:32, remaining: 14:07:25)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 14000-14099 to steam_app_data.csv. Batch 140 time: 0:02:58 (avg: 0:02:32, remaining: 14:05:54)
# Exported lines 14100-14199 to steam_app_data.csv. Batch 141 time: 0:02:07 (avg: 0:02:32, remaining: 14:02:22)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 14200-14299 to steam_app_data.csv. Batch 142 time: 0:02:58 (avg: 0:02:32, remaining: 14:00:49)
# Exported lines 14300-14399 to steam_app_data.csv. Batch 143 time: 0:02:07 (avg: 0:02:32, remaining: 13:57:19)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# Exported lines 14400-14499 to steam_app_data.csv. Batch 144 time: 0:02:48 (avg: 0:02:32, remaining: 13:55:21)
# Exported lines 14500-14599 to steam_app_data.csv. Batch 145 time: 0:02:07 (avg: 0:02:32, remaining: 13:51:51)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# Exported lines 14600-14699 to steam_app_data.csv. Batch 146 time: 0:02:48 (avg: 0:02:32, remaining: 13:49:54)
# Exported lines 14700-14799 to steam_app_data.csv. Batch 147 time: 0:02:07 (avg: 0:02:32, remaining: 13:46:25)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 14800-14899 to steam_app_data.csv. Batch 148 time: 0:02:58 (avg: 0:02:32, remaining: 13:44:49)
# Exported lines 14900-14999 to steam_app_data.csv. Batch 149 time: 0:02:07 (avg: 0:02:32, remaining: 13:41:22)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 15000-15099 to steam_app_data.csv. Batch 150 time: 0:02:58 (avg: 0:02:32, remaining: 13:39:45)
# Exported lines 15100-15199 to steam_app_data.csv. Batch 151 time: 0:02:07 (avg: 0:02:32, remaining: 13:36:19)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 15200-15299 to steam_app_data.csv. Batch 152 time: 0:02:57 (avg: 0:02:32, remaining: 13:34:40)
# Exported lines 15300-15399 to steam_app_data.csv. Batch 153 time: 0:02:06 (avg: 0:02:32, remaining: 13:31:13)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 15400-15499 to steam_app_data.csv. Batch 154 time: 0:02:58 (avg: 0:02:32, remaining: 13:29:33)
# Exported lines 15500-15599 to steam_app_data.csv. Batch 155 time: 0:02:09 (avg: 0:02:32, remaining: 13:26:13)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 15600-15699 to steam_app_data.csv. Batch 156 time: 0:02:57 (avg: 0:02:32, remaining: 13:24:32)
# Exported lines 15700-15799 to steam_app_data.csv. Batch 157 time: 0:02:07 (avg: 0:02:32, remaining: 13:21:09)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 15800-15899 to steam_app_data.csv. Batch 158 time: 0:02:58 (avg: 0:02:32, remaining: 13:19:28)
# Exported lines 15900-15999 to steam_app_data.csv. Batch 159 time: 0:02:06 (avg: 0:02:32, remaining: 13:16:05)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 16000-16099 to steam_app_data.csv. Batch 160 time: 0:02:58 (avg: 0:02:32, remaining: 13:14:23)
# Exported lines 16100-16199 to steam_app_data.csv. Batch 161 time: 0:02:07 (avg: 0:02:32, remaining: 13:11:01)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 16200-16299 to steam_app_data.csv. Batch 162 time: 0:02:57 (avg: 0:02:32, remaining: 13:09:17)
# Exported lines 16300-16399 to steam_app_data.csv. Batch 163 time: 0:02:08 (avg: 0:02:32, remaining: 13:05:58)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 16400-16499 to steam_app_data.csv. Batch 164 time: 0:02:58 (avg: 0:02:32, remaining: 13:04:15)
# Exported lines 16500-16599 to steam_app_data.csv. Batch 165 time: 0:02:07 (avg: 0:02:32, remaining: 13:00:55)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 16600-16699 to steam_app_data.csv. Batch 166 time: 0:02:58 (avg: 0:02:32, remaining: 12:59:09)
# Exported lines 16700-16799 to steam_app_data.csv. Batch 167 time: 0:02:07 (avg: 0:02:32, remaining: 12:55:51)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 16800-16899 to steam_app_data.csv. Batch 168 time: 0:02:58 (avg: 0:02:32, remaining: 12:54:05)
# Exported lines 16900-16999 to steam_app_data.csv. Batch 169 time: 0:02:07 (avg: 0:02:32, remaining: 12:50:47)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 17000-17099 to steam_app_data.csv. Batch 170 time: 0:02:58 (avg: 0:02:32, remaining: 12:49:00)
# Exported lines 17100-17199 to steam_app_data.csv. Batch 171 time: 0:02:07 (avg: 0:02:32, remaining: 12:45:42)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 17200-17299 to steam_app_data.csv. Batch 172 time: 0:02:57 (avg: 0:02:32, remaining: 12:43:54)
# Exported lines 17300-17399 to steam_app_data.csv. Batch 173 time: 0:02:06 (avg: 0:02:32, remaining: 12:40:37)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 17400-17499 to steam_app_data.csv. Batch 174 time: 0:02:58 (avg: 0:02:32, remaining: 12:38:49)
# Exported lines 17500-17599 to steam_app_data.csv. Batch 175 time: 0:02:07 (avg: 0:02:32, remaining: 12:35:34)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 17600-17699 to steam_app_data.csv. Batch 176 time: 0:02:58 (avg: 0:02:32, remaining: 12:33:46)
# Exported lines 17700-17799 to steam_app_data.csv. Batch 177 time: 0:02:06 (avg: 0:02:32, remaining: 12:30:31)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 17800-17899 to steam_app_data.csv. Batch 178 time: 0:02:57 (avg: 0:02:32, remaining: 12:28:41)
# Exported lines 17900-17999 to steam_app_data.csv. Batch 179 time: 0:02:06 (avg: 0:02:32, remaining: 12:25:25)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 18000-18099 to steam_app_data.csv. Batch 180 time: 0:02:58 (avg: 0:02:32, remaining: 12:23:34)
# Exported lines 18100-18199 to steam_app_data.csv. Batch 181 time: 0:02:07 (avg: 0:02:32, remaining: 12:20:21)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 18200-18299 to steam_app_data.csv. Batch 182 time: 0:02:58 (avg: 0:02:32, remaining: 12:18:30)
# Exported lines 18300-18399 to steam_app_data.csv. Batch 183 time: 0:02:07 (avg: 0:02:32, remaining: 12:15:18)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 18400-18499 to steam_app_data.csv. Batch 184 time: 0:02:57 (avg: 0:02:32, remaining: 12:13:26)
# Exported lines 18500-18599 to steam_app_data.csv. Batch 185 time: 0:02:07 (avg: 0:02:32, remaining: 12:10:14)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 18600-18699 to steam_app_data.csv. Batch 186 time: 0:02:57 (avg: 0:02:32, remaining: 12:08:20)
# Exported lines 18700-18799 to steam_app_data.csv. Batch 187 time: 0:02:07 (avg: 0:02:32, remaining: 12:05:09)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 18800-18899 to steam_app_data.csv. Batch 188 time: 0:02:58 (avg: 0:02:32, remaining: 12:03:16)
# Exported lines 18900-18999 to steam_app_data.csv. Batch 189 time: 0:02:07 (avg: 0:02:32, remaining: 12:00:06)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 19000-19099 to steam_app_data.csv. Batch 190 time: 0:02:58 (avg: 0:02:32, remaining: 11:58:12)
# Exported lines 19100-19199 to steam_app_data.csv. Batch 191 time: 0:02:06 (avg: 0:02:32, remaining: 11:55:02)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# No response, waiting 10 seconds...
# Retrying. Attempt # 6
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# ...
# Exported lines 30900-30999 to steam_app_data.csv. Batch 309 time: 0:02:07 (avg: 0:02:32, remaining: 6:56:18)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 31000-31099 to steam_app_data.csv. Batch 310 time: 0:02:59 (avg: 0:02:32, remaining: 6:53:59)
# Exported lines 31100-31199 to steam_app_data.csv. Batch 311 time: 0:02:06 (avg: 0:02:32, remaining: 6:51:13)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 31200-31299 to steam_app_data.csv. Batch 312 time: 0:05:05 (avg: 0:02:33, remaining: 6:50:00)
# Exported lines 31300-31399 to steam_app_data.csv. Batch 313 time: 0:02:07 (avg: 0:02:33, remaining: 6:47:14)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 31400-31499 to steam_app_data.csv. Batch 314 time: 0:02:58 (avg: 0:02:33, remaining: 6:44:54)
# Exported lines 31500-31599 to steam_app_data.csv. Batch 315 time: 0:02:07 (avg: 0:02:33, remaining: 6:42:08)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 31600-31699 to steam_app_data.csv. Batch 316 time: 0:02:58 (avg: 0:02:33, remaining: 6:39:48)
# Exported lines 31700-31799 to steam_app_data.csv. Batch 317 time: 0:02:08 (avg: 0:02:33, remaining: 6:37:03)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 31800-31899 to steam_app_data.csv. Batch 318 time: 0:02:59 (avg: 0:02:33, remaining: 6:34:43)
# Exported lines 31900-31999 to steam_app_data.csv. Batch 319 time: 0:02:08 (avg: 0:02:33, remaining: 6:31:58)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 32000-32099 to steam_app_data.csv. Batch 320 time: 0:02:58 (avg: 0:02:33, remaining: 6:29:37)
# Exported lines 32100-32199 to steam_app_data.csv. Batch 321 time: 0:02:07 (avg: 0:02:33, remaining: 6:26:52)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 32200-32299 to steam_app_data.csv. Batch 322 time: 0:02:59 (avg: 0:02:33, remaining: 6:24:32)
# Exported lines 32300-32399 to steam_app_data.csv. Batch 323 time: 0:02:08 (avg: 0:02:33, remaining: 6:21:47)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 32400-32499 to steam_app_data.csv. Batch 324 time: 0:02:58 (avg: 0:02:33, remaining: 6:19:26)
# Exported lines 32500-32599 to steam_app_data.csv. Batch 325 time: 0:02:07 (avg: 0:02:33, remaining: 6:16:42)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 32600-32699 to steam_app_data.csv. Batch 326 time: 0:03:05 (avg: 0:02:33, remaining: 6:14:24)
# Exported lines 32700-32799 to steam_app_data.csv. Batch 327 time: 0:02:22 (avg: 0:02:33, remaining: 6:11:46)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# Exported lines 32800-32899 to steam_app_data.csv. Batch 328 time: 0:02:43 (avg: 0:02:33, remaining: 6:09:18)
# Exported lines 32900-32999 to steam_app_data.csv. Batch 329 time: 0:02:24 (avg: 0:02:33, remaining: 6:06:41)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# Exported lines 33000-33099 to steam_app_data.csv. Batch 330 time: 0:02:50 (avg: 0:02:33, remaining: 6:04:16)
# Exported lines 33100-33199 to steam_app_data.csv. Batch 331 time: 0:02:27 (avg: 0:02:33, remaining: 6:01:41)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# Exported lines 33200-33299 to steam_app_data.csv. Batch 332 time: 0:02:41 (avg: 0:02:33, remaining: 5:59:11)
# Exported lines 33300-33399 to steam_app_data.csv. Batch 333 time: 0:02:23 (avg: 0:02:33, remaining: 5:56:34)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# Exported lines 33400-33499 to steam_app_data.csv. Batch 334 time: 0:02:39 (avg: 0:02:33, remaining: 5:54:04)
# Exported lines 33500-33599 to steam_app_data.csv. Batch 335 time: 0:02:07 (avg: 0:02:33, remaining: 5:51:21)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 33600-33699 to steam_app_data.csv. Batch 336 time: 0:02:58 (avg: 0:02:33, remaining: 5:48:58)
# Exported lines 33700-33799 to steam_app_data.csv. Batch 337 time: 0:02:07 (avg: 0:02:33, remaining: 5:46:15)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 33800-33899 to steam_app_data.csv. Batch 338 time: 0:02:58 (avg: 0:02:33, remaining: 5:43:52)
# Exported lines 33900-33999 to steam_app_data.csv. Batch 339 time: 0:02:07 (avg: 0:02:33, remaining: 5:41:09)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 34000-34099 to steam_app_data.csv. Batch 340 time: 0:02:58 (avg: 0:02:33, remaining: 5:38:46)
# Exported lines 34100-34199 to steam_app_data.csv. Batch 341 time: 0:02:07 (avg: 0:02:33, remaining: 5:36:03)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 34200-34299 to steam_app_data.csv. Batch 342 time: 0:02:59 (avg: 0:02:33, remaining: 5:33:40)
# Exported lines 34300-34399 to steam_app_data.csv. Batch 343 time: 0:02:08 (avg: 0:02:33, remaining: 5:30:58)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 34400-34499 to steam_app_data.csv. Batch 344 time: 0:03:01 (avg: 0:02:33, remaining: 5:28:36)
# Exported lines 34500-34599 to steam_app_data.csv. Batch 345 time: 0:02:07 (avg: 0:02:33, remaining: 5:25:54)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 34600-34699 to steam_app_data.csv. Batch 346 time: 0:02:59 (avg: 0:02:33, remaining: 5:23:30)
# Exported lines 34700-34799 to steam_app_data.csv. Batch 347 time: 0:02:07 (avg: 0:02:33, remaining: 5:20:48)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 34800-34899 to steam_app_data.csv. Batch 348 time: 0:02:59 (avg: 0:02:33, remaining: 5:18:25)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# Exported lines 34900-34999 to steam_app_data.csv. Batch 349 time: 0:02:20 (avg: 0:02:33, remaining: 5:15:47)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# Exported lines 35000-35099 to steam_app_data.csv. Batch 350 time: 0:02:44 (avg: 0:02:33, remaining: 5:13:19)
# Exported lines 35100-35199 to steam_app_data.csv. Batch 351 time: 0:02:08 (avg: 0:02:33, remaining: 5:10:37)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 35200-35299 to steam_app_data.csv. Batch 352 time: 0:03:00 (avg: 0:02:33, remaining: 5:08:14)
# Exported lines 35300-35399 to steam_app_data.csv. Batch 353 time: 0:02:09 (avg: 0:02:33, remaining: 5:05:33)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 35400-35499 to steam_app_data.csv. Batch 354 time: 0:02:59 (avg: 0:02:33, remaining: 5:03:09)
# Exported lines 35500-35599 to steam_app_data.csv. Batch 355 time: 0:02:08 (avg: 0:02:33, remaining: 5:00:28)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 35600-35699 to steam_app_data.csv. Batch 356 time: 0:02:59 (avg: 0:02:33, remaining: 4:58:04)
# Exported lines 35700-35799 to steam_app_data.csv. Batch 357 time: 0:02:09 (avg: 0:02:33, remaining: 4:55:23)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 35800-35899 to steam_app_data.csv. Batch 358 time: 0:02:58 (avg: 0:02:33, remaining: 4:52:58)
# Exported lines 35900-35999 to steam_app_data.csv. Batch 359 time: 0:02:07 (avg: 0:02:33, remaining: 4:50:17)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 36000-36099 to steam_app_data.csv. Batch 360 time: 0:02:59 (avg: 0:02:33, remaining: 4:47:53)
# Exported lines 36100-36199 to steam_app_data.csv. Batch 361 time: 0:02:07 (avg: 0:02:33, remaining: 4:45:12)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 36200-36299 to steam_app_data.csv. Batch 362 time: 0:02:58 (avg: 0:02:33, remaining: 4:42:47)
# Exported lines 36300-36399 to steam_app_data.csv. Batch 363 time: 0:02:07 (avg: 0:02:33, remaining: 4:40:06)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 36400-36499 to steam_app_data.csv. Batch 364 time: 0:02:59 (avg: 0:02:33, remaining: 4:37:41)
# Exported lines 36500-36599 to steam_app_data.csv. Batch 365 time: 0:02:08 (avg: 0:02:33, remaining: 4:35:01)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 36600-36699 to steam_app_data.csv. Batch 366 time: 0:02:59 (avg: 0:02:33, remaining: 4:32:36)
# Exported lines 36700-36799 to steam_app_data.csv. Batch 367 time: 0:02:08 (avg: 0:02:33, remaining: 4:29:55)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# Exported lines 36800-36899 to steam_app_data.csv. Batch 368 time: 0:02:59 (avg: 0:02:33, remaining: 4:27:30)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# No response, waiting 10 seconds...
# Retrying. Attempt # 2
# No response, waiting 10 seconds...
# Retrying. Attempt # 3
# No response, waiting 10 seconds...
# Retrying. Attempt # 4
# No response, waiting 10 seconds...
# Retrying. Attempt # 5
# No response, waiting 10 seconds...
# Retrying. Attempt # 6
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-424f52aee859> in <module>
#      51     index_filename=steam_index,
#      52     columns=steam_columns,
# ---> 53     begin=index
#      54 )
#
# <ipython-input-5-bea114aa8d6c> in process_batches(parser, app_list, download_path, data_filename, index_filename, columns, begin, end, batchsize, pause)
#      61         stop = batches[i+1]
#      62
# ---> 63         app_data = get_app_data(start, stop, parser, pause)
#      64
#      65         rel_path = os.path.join(download_path, data_filename)
#
# <ipython-input-5-bea114aa8d6c> in get_app_data(start, stop, parser, pause)
#      14
#      15         # retrive app data for a row, handled by supplied parser, and append to list
# ---> 16         data = parser(appid, name)
#      17         app_data.append(data)
#      18
#
# <ipython-input-8-424f52aee859> in parse_steam_request(appid, name)
#       7     parameters = {"appids": appid}
#       8
# ----> 9     json_data = get_request(url, parameters=parameters).json()
#      10     json_app_data = json_data[str(appid)]
#      11
#
# AttributeError: 'NoneType' object has no attribute 'json'

# %%
# inspect downloaded data
df = pd.read_csv('../data/download/steam_app_data.csv')

# %%
df.head(1)
# Out:
#    type            name  steam_appid  required_age is_free controller_support  \
# 0  game  Counter-Strike           10           0.0   False                NaN
#
#    dlc                               detailed_description  \
# 0  NaN  Play the world's number 1 online action game. ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
#
#                                    short_description  fullgame  \
# 0  Play the world's number 1 online action game. ...       NaN
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
#
#                                         header_image website  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...     NaN
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                     mac_requirements  \
# 0  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                   linux_requirements legal_notice drm_notice  \
# 0  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN        NaN
#
#   ext_user_account_notice developers publishers demos  \
# 0                     NaN  ['Valve']  ['Valve']   NaN
#
#                                       price_overview     packages  \
# 0  {'currency': 'USD', 'initial': 999, 'final': 9...  [574941, 7]
#
#                                       package_groups  \
# 0  [{'name': 'default', 'title': 'Buy Counter-Str...
#
#                                        platforms  \
# 0  {'windows': True, 'mac': True, 'linux': True}
#
#                                           metacritic reviews  \
# 0  {'score': 88, 'url': 'https://www.metacritic.c...     NaN
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
#
#                                    genres  \
# 0  [{'id': '1', 'description': 'Action'}]
#
#                                          screenshots movies  \
# 0  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...    NaN
#
#      recommendations achievements  \
# 0  {'total': 110752}          NaN
#
#                                     release_date  \
# 0  {'coming_soon': False, 'date': 'Nov 1, 2000'}
#
#                                         support_info  \
# 0  {'url': 'http://steamcommunity.com/app/10', 'e...
#
#                                           background  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                  content_descriptors
# 0  {'ids': [2, 5], 'notes': 'Includes intense vio...

# %% [markdown]
# ## Download SteamSpy data
#
# To retrieve data from SteamSpy we perform a very similar process. Our parse function is a little simpler because of the how data is returned, and the maximum polling rate of this API is higher so we can set a lower value for `pause` in the `process_batches` function and download more quickly. Apart from that we set the new variables and make a call to the `process_batches` function once again.

# %%
def parse_steamspy_request(appid, name):
    """Parser to handle SteamSpy API data."""
    url = "https://steamspy.com/api.php"
    parameters = {"request": "appdetails", "appid": appid}
    
    json_data = get_request(url, parameters).json()
    return json_data


# set files and columns
download_path = '../data/download'
steamspy_data = 'steamspy_data.csv'
steamspy_index = 'steamspy_index.txt'

steamspy_columns = [
    'appid', 'name', 'developer', 'publisher', 'score_rank', 'positive',
    'negative', 'userscore', 'owners', 'average_forever', 'average_2weeks',
    'median_forever', 'median_2weeks', 'price', 'initialprice', 'discount',
    'languages', 'genre', 'ccu', 'tags'
]

reset_index(download_path, steamspy_index)
index = get_index(download_path, steamspy_index)

# Wipe data file if index is 0
prepare_data_file(download_path, steamspy_data, index, steamspy_columns)

process_batches(
    parser=parse_steamspy_request,
    app_list=app_list,
    download_path=download_path, 
    data_filename=steamspy_data,
    index_filename=steamspy_index,
    columns=steamspy_columns,
    begin=index,
    pause=0.3
)
# Out:
# Starting at index 0:
#
# Exported lines 0-99 to steamspy_data.csv. Batch 0 time: 0:01:11 (avg: 0:01:11, remaining: 9:22:10)
# Exported lines 100-199 to steamspy_data.csv. Batch 1 time: 0:01:10 (avg: 0:01:11, remaining: 9:16:51)
# Exported lines 200-299 to steamspy_data.csv. Batch 2 time: 0:01:11 (avg: 0:01:11, remaining: 9:16:43)
# Exported lines 300-399 to steamspy_data.csv. Batch 3 time: 0:01:10 (avg: 0:01:11, remaining: 9:14:04)
# Exported lines 400-499 to steamspy_data.csv. Batch 4 time: 0:01:11 (avg: 0:01:11, remaining: 9:13:13)
# Exported lines 500-599 to steamspy_data.csv. Batch 5 time: 0:01:11 (avg: 0:01:11, remaining: 9:12:49)
# Exported lines 600-699 to steamspy_data.csv. Batch 6 time: 0:01:11 (avg: 0:01:11, remaining: 9:11:47)
# Exported lines 700-799 to steamspy_data.csv. Batch 7 time: 0:01:11 (avg: 0:01:11, remaining: 9:10:22)
# Exported lines 800-899 to steamspy_data.csv. Batch 8 time: 0:01:10 (avg: 0:01:11, remaining: 9:08:28)
# Exported lines 900-999 to steamspy_data.csv. Batch 9 time: 0:01:12 (avg: 0:01:11, remaining: 9:08:10)
# Exported lines 1000-1099 to steamspy_data.csv. Batch 10 time: 0:01:12 (avg: 0:01:11, remaining: 9:07:45)
# Exported lines 1100-1199 to steamspy_data.csv. Batch 11 time: 0:01:11 (avg: 0:01:11, remaining: 9:06:42)
# Exported lines 1200-1299 to steamspy_data.csv. Batch 12 time: 0:01:11 (avg: 0:01:11, remaining: 9:05:15)
# Exported lines 1300-1399 to steamspy_data.csv. Batch 13 time: 0:01:11 (avg: 0:01:11, remaining: 9:04:21)
# Exported lines 1400-1499 to steamspy_data.csv. Batch 14 time: 0:01:11 (avg: 0:01:11, remaining: 9:03:06)
# Exported lines 1500-1599 to steamspy_data.csv. Batch 15 time: 0:01:10 (avg: 0:01:11, remaining: 9:01:41)
# Exported lines 1600-1699 to steamspy_data.csv. Batch 16 time: 0:01:10 (avg: 0:01:11, remaining: 8:59:56)
# Exported lines 1700-1799 to steamspy_data.csv. Batch 17 time: 0:01:16 (avg: 0:01:11, remaining: 9:00:49)
# Exported lines 1800-1899 to steamspy_data.csv. Batch 18 time: 0:01:11 (avg: 0:01:11, remaining: 8:59:45)
# Exported lines 1900-1999 to steamspy_data.csv. Batch 19 time: 0:01:11 (avg: 0:01:11, remaining: 8:58:38)
# Exported lines 2000-2099 to steamspy_data.csv. Batch 20 time: 0:01:10 (avg: 0:01:11, remaining: 8:56:59)
# Exported lines 2100-2199 to steamspy_data.csv. Batch 21 time: 0:01:10 (avg: 0:01:11, remaining: 8:55:24)
# Exported lines 2200-2299 to steamspy_data.csv. Batch 22 time: 0:01:10 (avg: 0:01:11, remaining: 8:54:00)
# Exported lines 2300-2399 to steamspy_data.csv. Batch 23 time: 0:01:10 (avg: 0:01:11, remaining: 8:52:38)
# Exported lines 2400-2499 to steamspy_data.csv. Batch 24 time: 0:01:11 (avg: 0:01:11, remaining: 8:51:34)
# Exported lines 2500-2599 to steamspy_data.csv. Batch 25 time: 0:01:11 (avg: 0:01:11, remaining: 8:50:21)
# Exported lines 2600-2699 to steamspy_data.csv. Batch 26 time: 0:01:12 (avg: 0:01:11, remaining: 8:49:28)
# Exported lines 2700-2799 to steamspy_data.csv. Batch 27 time: 0:01:14 (avg: 0:01:11, remaining: 8:49:03)
# Exported lines 2800-2899 to steamspy_data.csv. Batch 28 time: 0:01:10 (avg: 0:01:11, remaining: 8:47:32)
# Exported lines 2900-2999 to steamspy_data.csv. Batch 29 time: 0:01:10 (avg: 0:01:11, remaining: 8:46:09)
# Exported lines 3000-3099 to steamspy_data.csv. Batch 30 time: 0:01:10 (avg: 0:01:11, remaining: 8:44:41)
# Exported lines 3100-3199 to steamspy_data.csv. Batch 31 time: 0:01:11 (avg: 0:01:11, remaining: 8:43:26)
# Exported lines 3200-3299 to steamspy_data.csv. Batch 32 time: 0:01:09 (avg: 0:01:11, remaining: 8:41:48)
# Exported lines 3300-3399 to steamspy_data.csv. Batch 33 time: 0:01:11 (avg: 0:01:11, remaining: 8:40:35)
# Exported lines 3400-3499 to steamspy_data.csv. Batch 34 time: 0:01:11 (avg: 0:01:11, remaining: 8:39:21)
# Exported lines 3500-3599 to steamspy_data.csv. Batch 35 time: 0:01:10 (avg: 0:01:11, remaining: 8:38:00)
# Exported lines 3600-3699 to steamspy_data.csv. Batch 36 time: 0:01:10 (avg: 0:01:11, remaining: 8:36:41)
# Exported lines 3700-3799 to steamspy_data.csv. Batch 37 time: 0:01:11 (avg: 0:01:11, remaining: 8:35:29)
# Exported lines 3800-3899 to steamspy_data.csv. Batch 38 time: 0:01:11 (avg: 0:01:11, remaining: 8:34:16)
# Exported lines 3900-3999 to steamspy_data.csv. Batch 39 time: 0:01:09 (avg: 0:01:11, remaining: 8:32:47)
# Exported lines 4000-4099 to steamspy_data.csv. Batch 40 time: 0:01:11 (avg: 0:01:11, remaining: 8:31:37)
# Exported lines 4100-4199 to steamspy_data.csv. Batch 41 time: 0:01:11 (avg: 0:01:11, remaining: 8:30:26)
# Exported lines 4200-4299 to steamspy_data.csv. Batch 42 time: 0:01:10 (avg: 0:01:11, remaining: 8:29:07)
# Exported lines 4300-4399 to steamspy_data.csv. Batch 43 time: 0:01:10 (avg: 0:01:11, remaining: 8:27:50)
# Exported lines 4400-4499 to steamspy_data.csv. Batch 44 time: 0:01:12 (avg: 0:01:11, remaining: 8:26:47)
# Exported lines 4500-4599 to steamspy_data.csv. Batch 45 time: 0:01:11 (avg: 0:01:11, remaining: 8:25:33)
# Exported lines 4600-4699 to steamspy_data.csv. Batch 46 time: 0:01:10 (avg: 0:01:11, remaining: 8:24:18)
# Exported lines 4700-4799 to steamspy_data.csv. Batch 47 time: 0:01:12 (avg: 0:01:11, remaining: 8:23:17)
# Exported lines 4800-4899 to steamspy_data.csv. Batch 48 time: 0:01:12 (avg: 0:01:11, remaining: 8:22:11)
# Exported lines 4900-4999 to steamspy_data.csv. Batch 49 time: 0:01:10 (avg: 0:01:11, remaining: 8:20:54)
# Exported lines 5000-5099 to steamspy_data.csv. Batch 50 time: 0:01:12 (avg: 0:01:11, remaining: 8:19:52)
# Exported lines 5100-5199 to steamspy_data.csv. Batch 51 time: 0:01:11 (avg: 0:01:11, remaining: 8:18:41)
# Exported lines 5200-5299 to steamspy_data.csv. Batch 52 time: 0:01:12 (avg: 0:01:11, remaining: 8:17:36)
# Exported lines 5300-5399 to steamspy_data.csv. Batch 53 time: 0:01:12 (avg: 0:01:11, remaining: 8:16:31)
# Exported lines 5400-5499 to steamspy_data.csv. Batch 54 time: 0:01:11 (avg: 0:01:11, remaining: 8:15:22)
# Exported lines 5500-5599 to steamspy_data.csv. Batch 55 time: 0:01:11 (avg: 0:01:11, remaining: 8:14:13)
# Exported lines 5600-5699 to steamspy_data.csv. Batch 56 time: 0:01:11 (avg: 0:01:11, remaining: 8:13:03)
# Exported lines 5700-5799 to steamspy_data.csv. Batch 57 time: 0:01:11 (avg: 0:01:11, remaining: 8:11:54)
# Exported lines 5800-5899 to steamspy_data.csv. Batch 58 time: 0:01:12 (avg: 0:01:11, remaining: 8:10:48)
# Exported lines 5900-5999 to steamspy_data.csv. Batch 59 time: 0:01:10 (avg: 0:01:11, remaining: 8:09:31)
# Exported lines 6000-6099 to steamspy_data.csv. Batch 60 time: 0:01:11 (avg: 0:01:11, remaining: 8:08:18)
# Exported lines 6100-6199 to steamspy_data.csv. Batch 61 time: 0:01:12 (avg: 0:01:11, remaining: 8:07:11)
# Exported lines 6200-6299 to steamspy_data.csv. Batch 62 time: 0:01:11 (avg: 0:01:11, remaining: 8:06:00)
# Exported lines 6300-6399 to steamspy_data.csv. Batch 63 time: 0:01:10 (avg: 0:01:11, remaining: 8:04:43)
# Exported lines 6400-6499 to steamspy_data.csv. Batch 64 time: 0:01:13 (avg: 0:01:11, remaining: 8:03:42)
# Exported lines 6500-6599 to steamspy_data.csv. Batch 65 time: 0:01:12 (avg: 0:01:11, remaining: 8:02:35)
# Exported lines 6600-6699 to steamspy_data.csv. Batch 66 time: 0:01:11 (avg: 0:01:11, remaining: 8:01:27)
# Exported lines 6700-6799 to steamspy_data.csv. Batch 67 time: 0:01:11 (avg: 0:01:11, remaining: 8:00:15)
# Exported lines 6800-6899 to steamspy_data.csv. Batch 68 time: 0:01:11 (avg: 0:01:11, remaining: 7:59:05)
# Exported lines 6900-6999 to steamspy_data.csv. Batch 69 time: 0:01:11 (avg: 0:01:11, remaining: 7:57:54)
# Exported lines 7000-7099 to steamspy_data.csv. Batch 70 time: 0:01:11 (avg: 0:01:11, remaining: 7:56:45)
# Exported lines 7100-7199 to steamspy_data.csv. Batch 71 time: 0:01:12 (avg: 0:01:11, remaining: 7:55:38)
# Exported lines 7200-7299 to steamspy_data.csv. Batch 72 time: 0:01:11 (avg: 0:01:11, remaining: 7:54:26)
# Exported lines 7300-7399 to steamspy_data.csv. Batch 73 time: 0:01:12 (avg: 0:01:11, remaining: 7:53:18)
# Exported lines 7400-7499 to steamspy_data.csv. Batch 74 time: 0:01:11 (avg: 0:01:11, remaining: 7:52:10)
# Exported lines 7500-7599 to steamspy_data.csv. Batch 75 time: 0:01:11 (avg: 0:01:11, remaining: 7:51:01)
# Exported lines 7600-7699 to steamspy_data.csv. Batch 76 time: 0:01:11 (avg: 0:01:11, remaining: 7:49:51)
# Exported lines 7700-7799 to steamspy_data.csv. Batch 77 time: 0:01:12 (avg: 0:01:11, remaining: 7:48:44)
# Exported lines 7800-7899 to steamspy_data.csv. Batch 78 time: 0:01:11 (avg: 0:01:11, remaining: 7:47:33)
# Exported lines 7900-7999 to steamspy_data.csv. Batch 79 time: 0:01:10 (avg: 0:01:11, remaining: 7:46:19)
# Exported lines 8000-8099 to steamspy_data.csv. Batch 80 time: 0:01:12 (avg: 0:01:11, remaining: 7:45:12)
# Exported lines 8100-8199 to steamspy_data.csv. Batch 81 time: 0:01:11 (avg: 0:01:11, remaining: 7:43:59)
# Exported lines 8200-8299 to steamspy_data.csv. Batch 82 time: 0:01:11 (avg: 0:01:11, remaining: 7:42:48)
# Exported lines 8300-8399 to steamspy_data.csv. Batch 83 time: 0:01:11 (avg: 0:01:11, remaining: 7:41:36)
# Exported lines 8400-8499 to steamspy_data.csv. Batch 84 time: 0:01:11 (avg: 0:01:11, remaining: 7:40:23)
# Exported lines 8500-8599 to steamspy_data.csv. Batch 85 time: 0:01:11 (avg: 0:01:11, remaining: 7:39:13)
# Exported lines 8600-8699 to steamspy_data.csv. Batch 86 time: 0:01:12 (avg: 0:01:11, remaining: 7:38:06)
# Exported lines 8700-8799 to steamspy_data.csv. Batch 87 time: 0:01:11 (avg: 0:01:11, remaining: 7:36:54)
# Exported lines 8800-8899 to steamspy_data.csv. Batch 88 time: 0:01:11 (avg: 0:01:11, remaining: 7:35:45)
# Exported lines 8900-8999 to steamspy_data.csv. Batch 89 time: 0:01:11 (avg: 0:01:11, remaining: 7:34:32)
# Exported lines 9000-9099 to steamspy_data.csv. Batch 90 time: 0:01:12 (avg: 0:01:11, remaining: 7:33:25)
# Exported lines 9100-9199 to steamspy_data.csv. Batch 91 time: 0:01:10 (avg: 0:01:11, remaining: 7:32:10)
# Exported lines 9200-9299 to steamspy_data.csv. Batch 92 time: 0:01:11 (avg: 0:01:11, remaining: 7:30:58)
# Exported lines 9300-9399 to steamspy_data.csv. Batch 93 time: 0:01:11 (avg: 0:01:11, remaining: 7:29:45)
# Exported lines 9400-9499 to steamspy_data.csv. Batch 94 time: 0:01:12 (avg: 0:01:11, remaining: 7:28:38)
# Exported lines 9500-9599 to steamspy_data.csv. Batch 95 time: 0:01:11 (avg: 0:01:11, remaining: 7:27:26)
# Exported lines 9600-9699 to steamspy_data.csv. Batch 96 time: 0:01:12 (avg: 0:01:11, remaining: 7:26:20)
# Exported lines 9700-9799 to steamspy_data.csv. Batch 97 time: 0:01:11 (avg: 0:01:11, remaining: 7:25:08)
# Exported lines 9800-9899 to steamspy_data.csv. Batch 98 time: 0:01:12 (avg: 0:01:11, remaining: 7:23:59)
# Exported lines 9900-9999 to steamspy_data.csv. Batch 99 time: 0:01:11 (avg: 0:01:11, remaining: 7:22:49)
# Exported lines 10000-10099 to steamspy_data.csv. Batch 100 time: 0:01:12 (avg: 0:01:11, remaining: 7:21:41)
# Exported lines 10100-10199 to steamspy_data.csv. Batch 101 time: 0:01:12 (avg: 0:01:11, remaining: 7:20:33)
# Exported lines 10200-10299 to steamspy_data.csv. Batch 102 time: 0:01:11 (avg: 0:01:11, remaining: 7:19:22)
# Exported lines 10300-10399 to steamspy_data.csv. Batch 103 time: 0:01:10 (avg: 0:01:11, remaining: 7:18:05)
# Exported lines 10400-10499 to steamspy_data.csv. Batch 104 time: 0:01:12 (avg: 0:01:11, remaining: 7:16:57)
# Exported lines 10500-10599 to steamspy_data.csv. Batch 105 time: 0:01:11 (avg: 0:01:11, remaining: 7:15:47)
# Exported lines 10600-10699 to steamspy_data.csv. Batch 106 time: 0:01:11 (avg: 0:01:11, remaining: 7:14:38)
# Exported lines 10700-10799 to steamspy_data.csv. Batch 107 time: 0:01:11 (avg: 0:01:11, remaining: 7:13:26)
# Exported lines 10800-10899 to steamspy_data.csv. Batch 108 time: 0:01:11 (avg: 0:01:11, remaining: 7:12:14)
# Exported lines 10900-10999 to steamspy_data.csv. Batch 109 time: 0:01:11 (avg: 0:01:11, remaining: 7:11:02)
# Exported lines 11000-11099 to steamspy_data.csv. Batch 110 time: 0:01:14 (avg: 0:01:11, remaining: 7:10:00)
# Exported lines 11100-11199 to steamspy_data.csv. Batch 111 time: 0:01:13 (avg: 0:01:11, remaining: 7:08:54)
# Exported lines 11200-11299 to steamspy_data.csv. Batch 112 time: 0:01:14 (avg: 0:01:11, remaining: 7:07:51)
# Exported lines 11300-11399 to steamspy_data.csv. Batch 113 time: 0:01:14 (avg: 0:01:11, remaining: 7:06:49)
# Exported lines 11400-11499 to steamspy_data.csv. Batch 114 time: 0:01:14 (avg: 0:01:11, remaining: 7:05:47)
# Exported lines 11500-11599 to steamspy_data.csv. Batch 115 time: 0:01:14 (avg: 0:01:11, remaining: 7:04:43)
# Exported lines 11600-11699 to steamspy_data.csv. Batch 116 time: 0:01:14 (avg: 0:01:11, remaining: 7:03:39)
# Exported lines 11700-11799 to steamspy_data.csv. Batch 117 time: 0:01:13 (avg: 0:01:11, remaining: 7:02:33)
# Exported lines 11800-11899 to steamspy_data.csv. Batch 118 time: 0:01:27 (avg: 0:01:11, remaining: 7:02:09)
# Exported lines 11900-11999 to steamspy_data.csv. Batch 119 time: 0:01:15 (avg: 0:01:11, remaining: 7:01:09)
# Exported lines 12000-12099 to steamspy_data.csv. Batch 120 time: 0:01:14 (avg: 0:01:11, remaining: 7:00:05)
# Exported lines 12100-12199 to steamspy_data.csv. Batch 121 time: 0:01:14 (avg: 0:01:11, remaining: 6:59:01)
# Exported lines 12200-12299 to steamspy_data.csv. Batch 122 time: 0:01:13 (avg: 0:01:11, remaining: 6:57:55)
# Exported lines 12300-12399 to steamspy_data.csv. Batch 123 time: 0:01:13 (avg: 0:01:11, remaining: 6:56:49)
# Exported lines 12400-12499 to steamspy_data.csv. Batch 124 time: 0:01:13 (avg: 0:01:11, remaining: 6:55:41)
# Exported lines 12500-12599 to steamspy_data.csv. Batch 125 time: 0:01:12 (avg: 0:01:11, remaining: 6:54:31)
# Exported lines 12600-12699 to steamspy_data.csv. Batch 126 time: 0:01:13 (avg: 0:01:11, remaining: 6:53:23)
# Exported lines 12700-12799 to steamspy_data.csv. Batch 127 time: 0:01:13 (avg: 0:01:11, remaining: 6:52:16)
# Exported lines 12800-12899 to steamspy_data.csv. Batch 128 time: 0:01:13 (avg: 0:01:12, remaining: 6:51:09)
# Exported lines 12900-12999 to steamspy_data.csv. Batch 129 time: 0:01:14 (avg: 0:01:12, remaining: 6:50:03)
# Exported lines 13000-13099 to steamspy_data.csv. Batch 130 time: 0:01:21 (avg: 0:01:12, remaining: 6:49:15)
# Exported lines 13100-13199 to steamspy_data.csv. Batch 131 time: 0:01:18 (avg: 0:01:12, remaining: 6:48:21)
# Exported lines 13200-13299 to steamspy_data.csv. Batch 132 time: 0:01:23 (avg: 0:01:12, remaining: 6:47:39)
# Exported lines 13300-13399 to steamspy_data.csv. Batch 133 time: 0:01:18 (avg: 0:01:12, remaining: 6:46:43)
# Exported lines 13400-13499 to steamspy_data.csv. Batch 134 time: 0:01:15 (avg: 0:01:12, remaining: 6:45:39)
# Exported lines 13500-13599 to steamspy_data.csv. Batch 135 time: 0:01:13 (avg: 0:01:12, remaining: 6:44:29)
# Exported lines 13600-13699 to steamspy_data.csv. Batch 136 time: 0:01:13 (avg: 0:01:12, remaining: 6:43:19)
# Exported lines 13700-13799 to steamspy_data.csv. Batch 137 time: 0:01:13 (avg: 0:01:12, remaining: 6:42:11)
# Exported lines 13800-13899 to steamspy_data.csv. Batch 138 time: 0:01:12 (avg: 0:01:12, remaining: 6:41:00)
# Exported lines 13900-13999 to steamspy_data.csv. Batch 139 time: 0:01:12 (avg: 0:01:12, remaining: 6:39:50)
# Exported lines 14000-14099 to steamspy_data.csv. Batch 140 time: 0:01:12 (avg: 0:01:12, remaining: 6:38:39)
# Exported lines 14100-14199 to steamspy_data.csv. Batch 141 time: 0:01:12 (avg: 0:01:12, remaining: 6:37:28)
# Exported lines 14200-14299 to steamspy_data.csv. Batch 142 time: 0:01:12 (avg: 0:01:12, remaining: 6:36:17)
# Exported lines 14300-14399 to steamspy_data.csv. Batch 143 time: 0:01:13 (avg: 0:01:12, remaining: 6:35:09)
# Exported lines 14400-14499 to steamspy_data.csv. Batch 144 time: 0:01:13 (avg: 0:01:12, remaining: 6:34:00)
# Exported lines 14500-14599 to steamspy_data.csv. Batch 145 time: 0:01:13 (avg: 0:01:12, remaining: 6:32:50)
# Exported lines 14600-14699 to steamspy_data.csv. Batch 146 time: 0:01:14 (avg: 0:01:12, remaining: 6:31:43)
# Exported lines 14700-14799 to steamspy_data.csv. Batch 147 time: 0:01:12 (avg: 0:01:12, remaining: 6:30:32)
# Exported lines 14800-14899 to steamspy_data.csv. Batch 148 time: 0:01:13 (avg: 0:01:12, remaining: 6:29:23)
# Exported lines 14900-14999 to steamspy_data.csv. Batch 149 time: 0:01:12 (avg: 0:01:12, remaining: 6:28:10)
# Exported lines 15000-15099 to steamspy_data.csv. Batch 150 time: 0:01:12 (avg: 0:01:12, remaining: 6:26:58)
# Exported lines 15100-15199 to steamspy_data.csv. Batch 151 time: 0:01:12 (avg: 0:01:12, remaining: 6:25:46)
# Exported lines 15200-15299 to steamspy_data.csv. Batch 152 time: 0:01:12 (avg: 0:01:12, remaining: 6:24:35)
# Exported lines 15300-15399 to steamspy_data.csv. Batch 153 time: 0:01:12 (avg: 0:01:12, remaining: 6:23:23)
# Exported lines 15400-15499 to steamspy_data.csv. Batch 154 time: 0:01:14 (avg: 0:01:12, remaining: 6:22:15)
# Exported lines 15500-15599 to steamspy_data.csv. Batch 155 time: 0:01:11 (avg: 0:01:12, remaining: 6:21:02)
# Exported lines 15600-15699 to steamspy_data.csv. Batch 156 time: 0:01:11 (avg: 0:01:12, remaining: 6:19:49)
# Exported lines 15700-15799 to steamspy_data.csv. Batch 157 time: 0:01:12 (avg: 0:01:12, remaining: 6:18:37)
# Exported lines 15800-15899 to steamspy_data.csv. Batch 158 time: 0:01:12 (avg: 0:01:12, remaining: 6:17:26)
# Exported lines 15900-15999 to steamspy_data.csv. Batch 159 time: 0:01:11 (avg: 0:01:12, remaining: 6:16:13)
# Exported lines 16000-16099 to steamspy_data.csv. Batch 160 time: 0:01:11 (avg: 0:01:12, remaining: 6:14:58)
# Exported lines 16100-16199 to steamspy_data.csv. Batch 161 time: 0:01:12 (avg: 0:01:12, remaining: 6:13:46)
# Exported lines 16200-16299 to steamspy_data.csv. Batch 162 time: 0:01:12 (avg: 0:01:12, remaining: 6:12:33)
# Exported lines 16300-16399 to steamspy_data.csv. Batch 163 time: 0:01:10 (avg: 0:01:12, remaining: 6:11:18)
# Exported lines 16400-16499 to steamspy_data.csv. Batch 164 time: 0:01:09 (avg: 0:01:12, remaining: 6:10:01)
# Exported lines 16500-16599 to steamspy_data.csv. Batch 165 time: 0:01:09 (avg: 0:01:12, remaining: 6:08:44)
# Exported lines 16600-16699 to steamspy_data.csv. Batch 166 time: 0:01:09 (avg: 0:01:12, remaining: 6:07:28)
# Exported lines 16700-16799 to steamspy_data.csv. Batch 167 time: 0:01:10 (avg: 0:01:12, remaining: 6:06:13)
# Exported lines 16800-16899 to steamspy_data.csv. Batch 168 time: 0:01:11 (avg: 0:01:12, remaining: 6:05:00)
# Exported lines 16900-16999 to steamspy_data.csv. Batch 169 time: 0:01:10 (avg: 0:01:12, remaining: 6:03:44)
# Exported lines 17000-17099 to steamspy_data.csv. Batch 170 time: 0:01:10 (avg: 0:01:12, remaining: 6:02:29)
# Exported lines 17100-17199 to steamspy_data.csv. Batch 171 time: 0:01:10 (avg: 0:01:12, remaining: 6:01:15)
# Exported lines 17200-17299 to steamspy_data.csv. Batch 172 time: 0:01:10 (avg: 0:01:12, remaining: 5:59:59)
# Exported lines 17300-17399 to steamspy_data.csv. Batch 173 time: 0:01:10 (avg: 0:01:12, remaining: 5:58:44)
# Exported lines 17400-17499 to steamspy_data.csv. Batch 174 time: 0:01:10 (avg: 0:01:12, remaining: 5:57:30)
# Exported lines 17500-17599 to steamspy_data.csv. Batch 175 time: 0:01:09 (avg: 0:01:12, remaining: 5:56:14)
# Exported lines 17600-17699 to steamspy_data.csv. Batch 176 time: 0:01:10 (avg: 0:01:12, remaining: 5:54:59)
# Exported lines 17700-17799 to steamspy_data.csv. Batch 177 time: 0:01:12 (avg: 0:01:12, remaining: 5:53:47)
# Exported lines 17800-17899 to steamspy_data.csv. Batch 178 time: 0:01:09 (avg: 0:01:12, remaining: 5:52:32)
# Exported lines 17900-17999 to steamspy_data.csv. Batch 179 time: 0:01:10 (avg: 0:01:12, remaining: 5:51:18)
# Exported lines 18000-18099 to steamspy_data.csv. Batch 180 time: 0:01:11 (avg: 0:01:12, remaining: 5:50:05)
# Exported lines 18100-18199 to steamspy_data.csv. Batch 181 time: 0:01:09 (avg: 0:01:12, remaining: 5:48:50)
# Exported lines 18200-18299 to steamspy_data.csv. Batch 182 time: 0:01:10 (avg: 0:01:12, remaining: 5:47:36)
# Exported lines 18300-18399 to steamspy_data.csv. Batch 183 time: 0:01:09 (avg: 0:01:12, remaining: 5:46:21)
# Exported lines 18400-18499 to steamspy_data.csv. Batch 184 time: 0:01:11 (avg: 0:01:12, remaining: 5:45:07)
# Exported lines 18500-18599 to steamspy_data.csv. Batch 185 time: 0:01:10 (avg: 0:01:12, remaining: 5:43:54)
# Exported lines 18600-18699 to steamspy_data.csv. Batch 186 time: 0:01:15 (avg: 0:01:12, remaining: 5:42:48)
# Exported lines 18700-18799 to steamspy_data.csv. Batch 187 time: 0:01:18 (avg: 0:01:12, remaining: 5:41:46)
# Exported lines 18800-18899 to steamspy_data.csv. Batch 188 time: 0:01:21 (avg: 0:01:12, remaining: 5:40:48)
# Exported lines 18900-18999 to steamspy_data.csv. Batch 189 time: 0:01:10 (avg: 0:01:12, remaining: 5:39:33)
# Exported lines 19000-19099 to steamspy_data.csv. Batch 190 time: 0:01:09 (avg: 0:01:12, remaining: 5:38:18)
# Exported lines 19100-19199 to steamspy_data.csv. Batch 191 time: 0:01:11 (avg: 0:01:12, remaining: 5:37:05)
# Exported lines 19200-19299 to steamspy_data.csv. Batch 192 time: 0:01:11 (avg: 0:01:12, remaining: 5:35:52)
# Exported lines 19300-19399 to steamspy_data.csv. Batch 193 time: 0:01:09 (avg: 0:01:12, remaining: 5:34:36)
# Exported lines 19400-19499 to steamspy_data.csv. Batch 194 time: 0:01:10 (avg: 0:01:12, remaining: 5:33:22)
# Exported lines 19500-19599 to steamspy_data.csv. Batch 195 time: 0:01:10 (avg: 0:01:12, remaining: 5:32:07)
# Exported lines 19600-19699 to steamspy_data.csv. Batch 196 time: 0:01:10 (avg: 0:01:12, remaining: 5:30:53)
# Exported lines 19700-19799 to steamspy_data.csv. Batch 197 time: 0:01:10 (avg: 0:01:12, remaining: 5:29:39)
# Exported lines 19800-19899 to steamspy_data.csv. Batch 198 time: 0:01:10 (avg: 0:01:12, remaining: 5:28:25)
# Exported lines 19900-19999 to steamspy_data.csv. Batch 199 time: 0:01:10 (avg: 0:01:12, remaining: 5:27:12)
# Exported lines 20000-20099 to steamspy_data.csv. Batch 200 time: 0:01:11 (avg: 0:01:12, remaining: 5:25:59)
# Exported lines 20100-20199 to steamspy_data.csv. Batch 201 time: 0:01:10 (avg: 0:01:12, remaining: 5:24:46)
# Exported lines 20200-20299 to steamspy_data.csv. Batch 202 time: 0:01:08 (avg: 0:01:12, remaining: 5:23:29)
# Exported lines 20300-20399 to steamspy_data.csv. Batch 203 time: 0:01:11 (avg: 0:01:12, remaining: 5:22:16)
# Exported lines 20400-20499 to steamspy_data.csv. Batch 204 time: 0:01:10 (avg: 0:01:12, remaining: 5:21:03)
# Exported lines 20500-20599 to steamspy_data.csv. Batch 205 time: 0:01:11 (avg: 0:01:12, remaining: 5:19:50)
# Exported lines 20600-20699 to steamspy_data.csv. Batch 206 time: 0:01:10 (avg: 0:01:12, remaining: 5:18:37)
# Exported lines 20700-20799 to steamspy_data.csv. Batch 207 time: 0:01:10 (avg: 0:01:12, remaining: 5:17:23)
# Exported lines 20800-20899 to steamspy_data.csv. Batch 208 time: 0:01:10 (avg: 0:01:12, remaining: 5:16:09)
# Exported lines 20900-20999 to steamspy_data.csv. Batch 209 time: 0:01:11 (avg: 0:01:12, remaining: 5:14:56)
# Exported lines 21000-21099 to steamspy_data.csv. Batch 210 time: 0:01:10 (avg: 0:01:12, remaining: 5:13:42)
# Exported lines 21100-21199 to steamspy_data.csv. Batch 211 time: 0:01:12 (avg: 0:01:12, remaining: 5:12:31)
# Exported lines 21200-21299 to steamspy_data.csv. Batch 212 time: 0:01:10 (avg: 0:01:12, remaining: 5:11:17)
# Exported lines 21300-21399 to steamspy_data.csv. Batch 213 time: 0:01:09 (avg: 0:01:12, remaining: 5:10:03)
# Exported lines 21400-21499 to steamspy_data.csv. Batch 214 time: 0:01:10 (avg: 0:01:12, remaining: 5:08:49)
# Exported lines 21500-21599 to steamspy_data.csv. Batch 215 time: 0:01:10 (avg: 0:01:12, remaining: 5:07:36)
# Exported lines 21600-21699 to steamspy_data.csv. Batch 216 time: 0:01:11 (avg: 0:01:12, remaining: 5:06:24)
# Exported lines 21700-21799 to steamspy_data.csv. Batch 217 time: 0:01:11 (avg: 0:01:12, remaining: 5:05:12)
# Exported lines 21800-21899 to steamspy_data.csv. Batch 218 time: 0:01:11 (avg: 0:01:12, remaining: 5:04:00)
# Exported lines 21900-21999 to steamspy_data.csv. Batch 219 time: 0:01:11 (avg: 0:01:12, remaining: 5:02:48)
# Exported lines 22000-22099 to steamspy_data.csv. Batch 220 time: 0:01:11 (avg: 0:01:12, remaining: 5:01:36)
# Exported lines 22100-22199 to steamspy_data.csv. Batch 221 time: 0:01:11 (avg: 0:01:12, remaining: 5:00:24)
# Exported lines 22200-22299 to steamspy_data.csv. Batch 222 time: 0:01:10 (avg: 0:01:12, remaining: 4:59:11)
# Exported lines 22300-22399 to steamspy_data.csv. Batch 223 time: 0:01:11 (avg: 0:01:12, remaining: 4:57:59)
# Exported lines 22400-22499 to steamspy_data.csv. Batch 224 time: 0:01:10 (avg: 0:01:12, remaining: 4:56:46)
# Exported lines 22500-22599 to steamspy_data.csv. Batch 225 time: 0:01:11 (avg: 0:01:12, remaining: 4:55:34)
# Exported lines 22600-22699 to steamspy_data.csv. Batch 226 time: 0:01:11 (avg: 0:01:12, remaining: 4:54:21)
# Exported lines 22700-22799 to steamspy_data.csv. Batch 227 time: 0:01:10 (avg: 0:01:11, remaining: 4:53:08)
# Exported lines 22800-22899 to steamspy_data.csv. Batch 228 time: 0:01:10 (avg: 0:01:11, remaining: 4:51:55)
# Exported lines 22900-22999 to steamspy_data.csv. Batch 229 time: 0:01:12 (avg: 0:01:11, remaining: 4:50:44)
# Exported lines 23000-23099 to steamspy_data.csv. Batch 230 time: 0:01:10 (avg: 0:01:11, remaining: 4:49:32)
# Exported lines 23100-23199 to steamspy_data.csv. Batch 231 time: 0:01:10 (avg: 0:01:11, remaining: 4:48:19)
# Exported lines 23200-23299 to steamspy_data.csv. Batch 232 time: 0:01:11 (avg: 0:01:11, remaining: 4:47:06)
# Exported lines 23300-23399 to steamspy_data.csv. Batch 233 time: 0:01:09 (avg: 0:01:11, remaining: 4:45:53)
# Exported lines 23400-23499 to steamspy_data.csv. Batch 234 time: 0:01:11 (avg: 0:01:11, remaining: 4:44:40)
# Exported lines 23500-23599 to steamspy_data.csv. Batch 235 time: 0:01:10 (avg: 0:01:11, remaining: 4:43:28)
# Exported lines 23600-23699 to steamspy_data.csv. Batch 236 time: 0:01:09 (avg: 0:01:11, remaining: 4:42:13)
# Exported lines 23700-23799 to steamspy_data.csv. Batch 237 time: 0:01:10 (avg: 0:01:11, remaining: 4:41:00)
# Exported lines 23800-23899 to steamspy_data.csv. Batch 238 time: 0:01:10 (avg: 0:01:11, remaining: 4:39:47)
# Exported lines 23900-23999 to steamspy_data.csv. Batch 239 time: 0:01:11 (avg: 0:01:11, remaining: 4:38:35)
# Exported lines 24000-24099 to steamspy_data.csv. Batch 240 time: 0:01:10 (avg: 0:01:11, remaining: 4:37:22)
# Exported lines 24100-24199 to steamspy_data.csv. Batch 241 time: 0:01:11 (avg: 0:01:11, remaining: 4:36:11)
# Exported lines 24200-24299 to steamspy_data.csv. Batch 242 time: 0:01:10 (avg: 0:01:11, remaining: 4:34:58)
# Exported lines 24300-24399 to steamspy_data.csv. Batch 243 time: 0:01:10 (avg: 0:01:11, remaining: 4:33:46)
# Exported lines 24400-24499 to steamspy_data.csv. Batch 244 time: 0:01:10 (avg: 0:01:11, remaining: 4:32:33)
# Exported lines 24500-24599 to steamspy_data.csv. Batch 245 time: 0:01:12 (avg: 0:01:11, remaining: 4:31:22)
# Exported lines 24600-24699 to steamspy_data.csv. Batch 246 time: 0:01:09 (avg: 0:01:11, remaining: 4:30:08)
# Exported lines 24700-24799 to steamspy_data.csv. Batch 247 time: 0:01:09 (avg: 0:01:11, remaining: 4:28:55)
# Exported lines 24800-24899 to steamspy_data.csv. Batch 248 time: 0:01:10 (avg: 0:01:11, remaining: 4:27:42)
# Exported lines 24900-24999 to steamspy_data.csv. Batch 249 time: 0:01:10 (avg: 0:01:11, remaining: 4:26:29)
# Exported lines 25000-25099 to steamspy_data.csv. Batch 250 time: 0:01:10 (avg: 0:01:11, remaining: 4:25:16)
# Exported lines 25100-25199 to steamspy_data.csv. Batch 251 time: 0:01:15 (avg: 0:01:11, remaining: 4:24:07)
# Exported lines 25200-25299 to steamspy_data.csv. Batch 252 time: 0:01:09 (avg: 0:01:11, remaining: 4:22:54)
# Exported lines 25300-25399 to steamspy_data.csv. Batch 253 time: 0:01:10 (avg: 0:01:11, remaining: 4:21:42)
# Exported lines 25400-25499 to steamspy_data.csv. Batch 254 time: 0:01:09 (avg: 0:01:11, remaining: 4:20:28)
# Exported lines 25500-25599 to steamspy_data.csv. Batch 255 time: 0:01:09 (avg: 0:01:11, remaining: 4:19:15)
# Exported lines 25600-25699 to steamspy_data.csv. Batch 256 time: 0:01:09 (avg: 0:01:11, remaining: 4:18:02)
# Exported lines 25700-25799 to steamspy_data.csv. Batch 257 time: 0:01:08 (avg: 0:01:11, remaining: 4:16:48)
# Exported lines 25800-25899 to steamspy_data.csv. Batch 258 time: 0:01:11 (avg: 0:01:11, remaining: 4:15:36)
# Exported lines 25900-25999 to steamspy_data.csv. Batch 259 time: 0:01:09 (avg: 0:01:11, remaining: 4:14:23)
# Exported lines 26000-26099 to steamspy_data.csv. Batch 260 time: 0:01:09 (avg: 0:01:11, remaining: 4:13:10)
# Exported lines 26100-26199 to steamspy_data.csv. Batch 261 time: 0:01:09 (avg: 0:01:11, remaining: 4:11:57)
# Exported lines 26200-26299 to steamspy_data.csv. Batch 262 time: 0:01:09 (avg: 0:01:11, remaining: 4:10:44)
# Exported lines 26300-26399 to steamspy_data.csv. Batch 263 time: 0:01:09 (avg: 0:01:11, remaining: 4:09:31)
# Exported lines 26400-26499 to steamspy_data.csv. Batch 264 time: 0:01:09 (avg: 0:01:11, remaining: 4:08:18)
# Exported lines 26500-26599 to steamspy_data.csv. Batch 265 time: 0:01:10 (avg: 0:01:11, remaining: 4:07:05)
# Exported lines 26600-26699 to steamspy_data.csv. Batch 266 time: 0:01:09 (avg: 0:01:11, remaining: 4:05:53)
# Exported lines 26700-26799 to steamspy_data.csv. Batch 267 time: 0:01:10 (avg: 0:01:11, remaining: 4:04:40)
# Exported lines 26800-26899 to steamspy_data.csv. Batch 268 time: 0:01:09 (avg: 0:01:11, remaining: 4:03:27)
# Exported lines 26900-26999 to steamspy_data.csv. Batch 269 time: 0:01:10 (avg: 0:01:11, remaining: 4:02:15)
# Exported lines 27000-27099 to steamspy_data.csv. Batch 270 time: 0:01:08 (avg: 0:01:11, remaining: 4:01:01)
# Exported lines 27100-27199 to steamspy_data.csv. Batch 271 time: 0:01:10 (avg: 0:01:11, remaining: 3:59:48)
# Exported lines 27200-27299 to steamspy_data.csv. Batch 272 time: 0:01:09 (avg: 0:01:11, remaining: 3:58:35)
# Exported lines 27300-27399 to steamspy_data.csv. Batch 273 time: 0:01:09 (avg: 0:01:11, remaining: 3:57:23)
# Exported lines 27400-27499 to steamspy_data.csv. Batch 274 time: 0:01:09 (avg: 0:01:11, remaining: 3:56:10)
# Exported lines 27500-27599 to steamspy_data.csv. Batch 275 time: 0:01:09 (avg: 0:01:11, remaining: 3:54:57)
# Exported lines 27600-27699 to steamspy_data.csv. Batch 276 time: 0:01:09 (avg: 0:01:11, remaining: 3:53:44)
# Exported lines 27700-27799 to steamspy_data.csv. Batch 277 time: 0:01:09 (avg: 0:01:11, remaining: 3:52:32)
# Exported lines 27800-27899 to steamspy_data.csv. Batch 278 time: 0:01:09 (avg: 0:01:11, remaining: 3:51:19)
# Exported lines 27900-27999 to steamspy_data.csv. Batch 279 time: 0:01:10 (avg: 0:01:11, remaining: 3:50:07)
# Exported lines 28000-28099 to steamspy_data.csv. Batch 280 time: 0:01:09 (avg: 0:01:11, remaining: 3:48:54)
# Exported lines 28100-28199 to steamspy_data.csv. Batch 281 time: 0:01:11 (avg: 0:01:11, remaining: 3:47:43)
# Exported lines 28200-28299 to steamspy_data.csv. Batch 282 time: 0:01:10 (avg: 0:01:11, remaining: 3:46:31)
# Exported lines 28300-28399 to steamspy_data.csv. Batch 283 time: 0:01:09 (avg: 0:01:11, remaining: 3:45:18)
# Exported lines 28400-28499 to steamspy_data.csv. Batch 284 time: 0:01:10 (avg: 0:01:11, remaining: 3:44:06)
# Exported lines 28500-28599 to steamspy_data.csv. Batch 285 time: 0:01:10 (avg: 0:01:11, remaining: 3:42:54)
# Exported lines 28600-28699 to steamspy_data.csv. Batch 286 time: 0:01:09 (avg: 0:01:11, remaining: 3:41:42)
# Exported lines 28700-28799 to steamspy_data.csv. Batch 287 time: 0:01:10 (avg: 0:01:11, remaining: 3:40:30)
# Exported lines 28800-28899 to steamspy_data.csv. Batch 288 time: 0:01:08 (avg: 0:01:11, remaining: 3:39:17)
# Exported lines 28900-28999 to steamspy_data.csv. Batch 289 time: 0:01:09 (avg: 0:01:11, remaining: 3:38:04)
# Exported lines 29000-29099 to steamspy_data.csv. Batch 290 time: 0:01:09 (avg: 0:01:11, remaining: 3:36:52)
# Exported lines 29100-29199 to steamspy_data.csv. Batch 291 time: 0:01:10 (avg: 0:01:11, remaining: 3:35:40)
# Exported lines 29200-29299 to steamspy_data.csv. Batch 292 time: 0:01:08 (avg: 0:01:11, remaining: 3:34:27)
# Exported lines 29300-29399 to steamspy_data.csv. Batch 293 time: 0:01:09 (avg: 0:01:11, remaining: 3:33:15)
# Exported lines 29400-29499 to steamspy_data.csv. Batch 294 time: 0:01:09 (avg: 0:01:11, remaining: 3:32:02)
# Exported lines 29500-29599 to steamspy_data.csv. Batch 295 time: 0:01:09 (avg: 0:01:11, remaining: 3:30:50)
# Exported lines 29600-29699 to steamspy_data.csv. Batch 296 time: 0:01:10 (avg: 0:01:11, remaining: 3:29:38)
# Exported lines 29700-29799 to steamspy_data.csv. Batch 297 time: 0:01:09 (avg: 0:01:11, remaining: 3:28:26)
# Exported lines 29800-29899 to steamspy_data.csv. Batch 298 time: 0:01:09 (avg: 0:01:11, remaining: 3:27:14)
# Exported lines 29900-29999 to steamspy_data.csv. Batch 299 time: 0:01:09 (avg: 0:01:11, remaining: 3:26:02)
# Exported lines 30000-30099 to steamspy_data.csv. Batch 300 time: 0:01:08 (avg: 0:01:11, remaining: 3:24:49)
# Exported lines 30100-30199 to steamspy_data.csv. Batch 301 time: 0:01:09 (avg: 0:01:11, remaining: 3:23:37)
# Exported lines 30200-30299 to steamspy_data.csv. Batch 302 time: 0:01:09 (avg: 0:01:11, remaining: 3:22:25)
# Exported lines 30300-30399 to steamspy_data.csv. Batch 303 time: 0:01:08 (avg: 0:01:11, remaining: 3:21:12)
# Exported lines 30400-30499 to steamspy_data.csv. Batch 304 time: 0:01:10 (avg: 0:01:11, remaining: 3:20:00)
# Exported lines 30500-30599 to steamspy_data.csv. Batch 305 time: 0:01:09 (avg: 0:01:11, remaining: 3:18:48)
# Exported lines 30600-30699 to steamspy_data.csv. Batch 306 time: 0:01:09 (avg: 0:01:11, remaining: 3:17:36)
# Exported lines 30700-30799 to steamspy_data.csv. Batch 307 time: 0:01:09 (avg: 0:01:11, remaining: 3:16:24)
# Exported lines 30800-30899 to steamspy_data.csv. Batch 308 time: 0:01:09 (avg: 0:01:11, remaining: 3:15:12)
# Exported lines 30900-30999 to steamspy_data.csv. Batch 309 time: 0:01:09 (avg: 0:01:11, remaining: 3:14:00)
# Exported lines 31000-31099 to steamspy_data.csv. Batch 310 time: 0:01:10 (avg: 0:01:11, remaining: 3:12:49)
# Exported lines 31100-31199 to steamspy_data.csv. Batch 311 time: 0:01:09 (avg: 0:01:11, remaining: 3:11:37)
# Exported lines 31200-31299 to steamspy_data.csv. Batch 312 time: 0:01:11 (avg: 0:01:11, remaining: 3:10:26)
# Exported lines 31300-31399 to steamspy_data.csv. Batch 313 time: 0:01:10 (avg: 0:01:11, remaining: 3:09:14)
# Exported lines 31400-31499 to steamspy_data.csv. Batch 314 time: 0:01:11 (avg: 0:01:11, remaining: 3:08:03)
# Exported lines 31500-31599 to steamspy_data.csv. Batch 315 time: 0:01:09 (avg: 0:01:11, remaining: 3:06:52)
# Exported lines 31600-31699 to steamspy_data.csv. Batch 316 time: 0:01:10 (avg: 0:01:11, remaining: 3:05:40)
# Exported lines 31700-31799 to steamspy_data.csv. Batch 317 time: 0:01:09 (avg: 0:01:11, remaining: 3:04:28)
# Exported lines 31800-31899 to steamspy_data.csv. Batch 318 time: 0:01:10 (avg: 0:01:11, remaining: 3:03:16)
# Exported lines 31900-31999 to steamspy_data.csv. Batch 319 time: 0:01:10 (avg: 0:01:11, remaining: 3:02:05)
# Exported lines 32000-32099 to steamspy_data.csv. Batch 320 time: 0:01:12 (avg: 0:01:11, remaining: 3:00:54)
# Exported lines 32100-32199 to steamspy_data.csv. Batch 321 time: 0:01:12 (avg: 0:01:11, remaining: 2:59:44)
# Exported lines 32200-32299 to steamspy_data.csv. Batch 322 time: 0:01:11 (avg: 0:01:11, remaining: 2:58:33)
# Exported lines 32300-32399 to steamspy_data.csv. Batch 323 time: 0:01:09 (avg: 0:01:11, remaining: 2:57:22)
# Exported lines 32400-32499 to steamspy_data.csv. Batch 324 time: 0:01:11 (avg: 0:01:11, remaining: 2:56:11)
# Exported lines 32500-32599 to steamspy_data.csv. Batch 325 time: 0:01:09 (avg: 0:01:11, remaining: 2:54:59)
# Exported lines 32600-32699 to steamspy_data.csv. Batch 326 time: 0:01:09 (avg: 0:01:11, remaining: 2:53:47)
# Exported lines 32700-32799 to steamspy_data.csv. Batch 327 time: 0:01:10 (avg: 0:01:11, remaining: 2:52:36)
# Exported lines 32800-32899 to steamspy_data.csv. Batch 328 time: 0:01:10 (avg: 0:01:11, remaining: 2:51:25)
# Exported lines 32900-32999 to steamspy_data.csv. Batch 329 time: 0:01:09 (avg: 0:01:11, remaining: 2:50:13)
# Exported lines 33000-33099 to steamspy_data.csv. Batch 330 time: 0:01:10 (avg: 0:01:11, remaining: 2:49:02)
# Exported lines 33100-33199 to steamspy_data.csv. Batch 331 time: 0:01:11 (avg: 0:01:11, remaining: 2:47:51)
# Exported lines 33200-33299 to steamspy_data.csv. Batch 332 time: 0:01:11 (avg: 0:01:11, remaining: 2:46:40)
# Exported lines 33300-33399 to steamspy_data.csv. Batch 333 time: 0:01:09 (avg: 0:01:11, remaining: 2:45:28)
# Exported lines 33400-33499 to steamspy_data.csv. Batch 334 time: 0:01:10 (avg: 0:01:11, remaining: 2:44:17)
# Exported lines 33500-33599 to steamspy_data.csv. Batch 335 time: 0:01:10 (avg: 0:01:11, remaining: 2:43:05)
# Exported lines 33600-33699 to steamspy_data.csv. Batch 336 time: 0:01:10 (avg: 0:01:11, remaining: 2:41:54)
# Exported lines 33700-33799 to steamspy_data.csv. Batch 337 time: 0:01:09 (avg: 0:01:11, remaining: 2:40:42)
# Exported lines 33800-33899 to steamspy_data.csv. Batch 338 time: 0:01:09 (avg: 0:01:11, remaining: 2:39:31)
# Exported lines 33900-33999 to steamspy_data.csv. Batch 339 time: 0:01:10 (avg: 0:01:11, remaining: 2:38:19)
# Exported lines 34000-34099 to steamspy_data.csv. Batch 340 time: 0:01:10 (avg: 0:01:11, remaining: 2:37:08)
# Exported lines 34100-34199 to steamspy_data.csv. Batch 341 time: 0:01:09 (avg: 0:01:11, remaining: 2:35:57)
# Exported lines 34200-34299 to steamspy_data.csv. Batch 342 time: 0:01:11 (avg: 0:01:11, remaining: 2:34:46)
# Exported lines 34300-34399 to steamspy_data.csv. Batch 343 time: 0:01:09 (avg: 0:01:11, remaining: 2:33:34)
# Exported lines 34400-34499 to steamspy_data.csv. Batch 344 time: 0:01:10 (avg: 0:01:11, remaining: 2:32:23)
# Exported lines 34500-34599 to steamspy_data.csv. Batch 345 time: 0:01:11 (avg: 0:01:11, remaining: 2:31:12)
# Exported lines 34600-34699 to steamspy_data.csv. Batch 346 time: 0:01:09 (avg: 0:01:11, remaining: 2:30:01)
# Exported lines 34700-34799 to steamspy_data.csv. Batch 347 time: 0:01:12 (avg: 0:01:11, remaining: 2:28:50)
# Exported lines 34800-34899 to steamspy_data.csv. Batch 348 time: 0:01:08 (avg: 0:01:11, remaining: 2:27:38)
# Exported lines 34900-34999 to steamspy_data.csv. Batch 349 time: 0:01:10 (avg: 0:01:11, remaining: 2:26:27)
# Exported lines 35000-35099 to steamspy_data.csv. Batch 350 time: 0:01:10 (avg: 0:01:11, remaining: 2:25:16)
# Exported lines 35100-35199 to steamspy_data.csv. Batch 351 time: 0:01:10 (avg: 0:01:11, remaining: 2:24:05)
# Exported lines 35200-35299 to steamspy_data.csv. Batch 352 time: 0:01:10 (avg: 0:01:11, remaining: 2:22:53)
# Exported lines 35300-35399 to steamspy_data.csv. Batch 353 time: 0:01:10 (avg: 0:01:11, remaining: 2:21:42)
# Exported lines 35400-35499 to steamspy_data.csv. Batch 354 time: 0:01:10 (avg: 0:01:11, remaining: 2:20:31)
# Exported lines 35500-35599 to steamspy_data.csv. Batch 355 time: 0:01:09 (avg: 0:01:11, remaining: 2:19:20)
# Exported lines 35600-35699 to steamspy_data.csv. Batch 356 time: 0:01:09 (avg: 0:01:11, remaining: 2:18:08)
# Exported lines 35700-35799 to steamspy_data.csv. Batch 357 time: 0:01:09 (avg: 0:01:11, remaining: 2:16:57)
# Exported lines 35800-35899 to steamspy_data.csv. Batch 358 time: 0:01:10 (avg: 0:01:11, remaining: 2:15:46)
# Exported lines 35900-35999 to steamspy_data.csv. Batch 359 time: 0:01:10 (avg: 0:01:11, remaining: 2:14:35)
# Exported lines 36000-36099 to steamspy_data.csv. Batch 360 time: 0:01:10 (avg: 0:01:11, remaining: 2:13:24)
# Exported lines 36100-36199 to steamspy_data.csv. Batch 361 time: 0:01:09 (avg: 0:01:11, remaining: 2:12:12)
# Exported lines 36200-36299 to steamspy_data.csv. Batch 362 time: 0:01:09 (avg: 0:01:11, remaining: 2:11:01)
# Exported lines 36300-36399 to steamspy_data.csv. Batch 363 time: 0:01:09 (avg: 0:01:11, remaining: 2:09:50)
# Exported lines 36400-36499 to steamspy_data.csv. Batch 364 time: 0:01:10 (avg: 0:01:11, remaining: 2:08:38)
# Exported lines 36500-36599 to steamspy_data.csv. Batch 365 time: 0:01:08 (avg: 0:01:11, remaining: 2:07:27)
# Exported lines 36600-36699 to steamspy_data.csv. Batch 366 time: 0:01:10 (avg: 0:01:11, remaining: 2:06:16)
# Exported lines 36700-36799 to steamspy_data.csv. Batch 367 time: 0:01:09 (avg: 0:01:11, remaining: 2:05:04)
# Exported lines 36800-36899 to steamspy_data.csv. Batch 368 time: 0:01:10 (avg: 0:01:11, remaining: 2:03:53)
# Exported lines 36900-36999 to steamspy_data.csv. Batch 369 time: 0:01:08 (avg: 0:01:11, remaining: 2:02:42)
# Exported lines 37000-37099 to steamspy_data.csv. Batch 370 time: 0:01:08 (avg: 0:01:11, remaining: 2:01:30)
# Exported lines 37100-37199 to steamspy_data.csv. Batch 371 time: 0:01:09 (avg: 0:01:11, remaining: 2:00:19)
# Exported lines 37200-37299 to steamspy_data.csv. Batch 372 time: 0:01:10 (avg: 0:01:11, remaining: 1:59:08)
# Exported lines 37300-37399 to steamspy_data.csv. Batch 373 time: 0:01:10 (avg: 0:01:11, remaining: 1:57:57)
# Exported lines 37400-37499 to steamspy_data.csv. Batch 374 time: 0:01:09 (avg: 0:01:11, remaining: 1:56:46)
# Exported lines 37500-37599 to steamspy_data.csv. Batch 375 time: 0:01:10 (avg: 0:01:11, remaining: 1:55:35)
# Exported lines 37600-37699 to steamspy_data.csv. Batch 376 time: 0:01:09 (avg: 0:01:11, remaining: 1:54:24)
# Exported lines 37700-37799 to steamspy_data.csv. Batch 377 time: 0:01:09 (avg: 0:01:11, remaining: 1:53:13)
# Exported lines 37800-37899 to steamspy_data.csv. Batch 378 time: 0:01:09 (avg: 0:01:11, remaining: 1:52:01)
# Exported lines 37900-37999 to steamspy_data.csv. Batch 379 time: 0:01:09 (avg: 0:01:11, remaining: 1:50:50)
# Exported lines 38000-38099 to steamspy_data.csv. Batch 380 time: 0:01:09 (avg: 0:01:11, remaining: 1:49:39)
# Exported lines 38100-38199 to steamspy_data.csv. Batch 381 time: 0:01:09 (avg: 0:01:11, remaining: 1:48:28)
# Exported lines 38200-38299 to steamspy_data.csv. Batch 382 time: 0:01:09 (avg: 0:01:11, remaining: 1:47:17)
# Exported lines 38300-38399 to steamspy_data.csv. Batch 383 time: 0:01:09 (avg: 0:01:11, remaining: 1:46:06)
# Exported lines 38400-38499 to steamspy_data.csv. Batch 384 time: 0:01:09 (avg: 0:01:11, remaining: 1:44:54)
# Exported lines 38500-38599 to steamspy_data.csv. Batch 385 time: 0:01:09 (avg: 0:01:11, remaining: 1:43:43)
# Exported lines 38600-38699 to steamspy_data.csv. Batch 386 time: 0:01:08 (avg: 0:01:11, remaining: 1:42:32)
# Exported lines 38700-38799 to steamspy_data.csv. Batch 387 time: 0:01:10 (avg: 0:01:11, remaining: 1:41:21)
# Exported lines 38800-38899 to steamspy_data.csv. Batch 388 time: 0:01:08 (avg: 0:01:11, remaining: 1:40:10)
# Exported lines 38900-38999 to steamspy_data.csv. Batch 389 time: 0:01:08 (avg: 0:01:11, remaining: 1:38:59)
# Exported lines 39000-39099 to steamspy_data.csv. Batch 390 time: 0:01:09 (avg: 0:01:11, remaining: 1:37:48)
# Exported lines 39100-39199 to steamspy_data.csv. Batch 391 time: 0:01:08 (avg: 0:01:11, remaining: 1:36:37)
# Exported lines 39200-39299 to steamspy_data.csv. Batch 392 time: 0:01:08 (avg: 0:01:11, remaining: 1:35:25)
# Exported lines 39300-39399 to steamspy_data.csv. Batch 393 time: 0:01:09 (avg: 0:01:11, remaining: 1:34:14)
# Exported lines 39400-39499 to steamspy_data.csv. Batch 394 time: 0:01:09 (avg: 0:01:11, remaining: 1:33:03)
# Exported lines 39500-39599 to steamspy_data.csv. Batch 395 time: 0:01:08 (avg: 0:01:11, remaining: 1:31:52)
# Exported lines 39600-39699 to steamspy_data.csv. Batch 396 time: 0:01:09 (avg: 0:01:11, remaining: 1:30:41)
# Exported lines 39700-39799 to steamspy_data.csv. Batch 397 time: 0:01:08 (avg: 0:01:11, remaining: 1:29:30)
# Exported lines 39800-39899 to steamspy_data.csv. Batch 398 time: 0:01:09 (avg: 0:01:11, remaining: 1:28:19)
# Exported lines 39900-39999 to steamspy_data.csv. Batch 399 time: 0:01:08 (avg: 0:01:11, remaining: 1:27:08)
# Exported lines 40000-40099 to steamspy_data.csv. Batch 400 time: 0:01:09 (avg: 0:01:11, remaining: 1:25:57)
# Exported lines 40100-40199 to steamspy_data.csv. Batch 401 time: 0:01:09 (avg: 0:01:11, remaining: 1:24:46)
# Exported lines 40200-40299 to steamspy_data.csv. Batch 402 time: 0:01:08 (avg: 0:01:11, remaining: 1:23:35)
# Exported lines 40300-40399 to steamspy_data.csv. Batch 403 time: 0:01:09 (avg: 0:01:11, remaining: 1:22:24)
# Exported lines 40400-40499 to steamspy_data.csv. Batch 404 time: 0:01:08 (avg: 0:01:11, remaining: 1:21:13)
# Exported lines 40500-40599 to steamspy_data.csv. Batch 405 time: 0:01:08 (avg: 0:01:11, remaining: 1:20:02)
# Exported lines 40600-40699 to steamspy_data.csv. Batch 406 time: 0:01:09 (avg: 0:01:11, remaining: 1:18:51)
# Exported lines 40700-40799 to steamspy_data.csv. Batch 407 time: 0:01:09 (avg: 0:01:11, remaining: 1:17:40)
# Exported lines 40800-40899 to steamspy_data.csv. Batch 408 time: 0:01:09 (avg: 0:01:11, remaining: 1:16:29)
# Exported lines 40900-40999 to steamspy_data.csv. Batch 409 time: 0:01:09 (avg: 0:01:11, remaining: 1:15:18)
# Exported lines 41000-41099 to steamspy_data.csv. Batch 410 time: 0:01:09 (avg: 0:01:11, remaining: 1:14:07)
# Exported lines 41100-41199 to steamspy_data.csv. Batch 411 time: 0:01:09 (avg: 0:01:11, remaining: 1:12:57)
# Exported lines 41200-41299 to steamspy_data.csv. Batch 412 time: 0:01:10 (avg: 0:01:11, remaining: 1:11:46)
# Exported lines 41300-41399 to steamspy_data.csv. Batch 413 time: 0:01:08 (avg: 0:01:11, remaining: 1:10:35)
# Exported lines 41400-41499 to steamspy_data.csv. Batch 414 time: 0:01:08 (avg: 0:01:11, remaining: 1:09:24)
# Exported lines 41500-41599 to steamspy_data.csv. Batch 415 time: 0:01:08 (avg: 0:01:11, remaining: 1:08:13)
# Exported lines 41600-41699 to steamspy_data.csv. Batch 416 time: 0:01:09 (avg: 0:01:11, remaining: 1:07:02)
# Exported lines 41700-41799 to steamspy_data.csv. Batch 417 time: 0:01:09 (avg: 0:01:11, remaining: 1:05:52)
# Exported lines 41800-41899 to steamspy_data.csv. Batch 418 time: 0:01:09 (avg: 0:01:11, remaining: 1:04:41)
# Exported lines 41900-41999 to steamspy_data.csv. Batch 419 time: 0:01:08 (avg: 0:01:11, remaining: 1:03:30)
# Exported lines 42000-42099 to steamspy_data.csv. Batch 420 time: 0:01:10 (avg: 0:01:11, remaining: 1:02:19)
# Exported lines 42100-42199 to steamspy_data.csv. Batch 421 time: 0:01:08 (avg: 0:01:11, remaining: 1:01:08)
# Exported lines 42200-42299 to steamspy_data.csv. Batch 422 time: 0:01:07 (avg: 0:01:11, remaining: 0:59:57)
# Exported lines 42300-42399 to steamspy_data.csv. Batch 423 time: 0:01:08 (avg: 0:01:11, remaining: 0:58:47)
# Exported lines 42400-42499 to steamspy_data.csv. Batch 424 time: 0:01:09 (avg: 0:01:11, remaining: 0:57:36)
# Exported lines 42500-42599 to steamspy_data.csv. Batch 425 time: 0:01:09 (avg: 0:01:11, remaining: 0:56:25)
# Exported lines 42600-42699 to steamspy_data.csv. Batch 426 time: 0:01:09 (avg: 0:01:11, remaining: 0:55:15)
# Exported lines 42700-42799 to steamspy_data.csv. Batch 427 time: 0:01:09 (avg: 0:01:11, remaining: 0:54:04)
# Exported lines 42800-42899 to steamspy_data.csv. Batch 428 time: 0:01:09 (avg: 0:01:11, remaining: 0:52:53)
# Exported lines 42900-42999 to steamspy_data.csv. Batch 429 time: 0:01:08 (avg: 0:01:11, remaining: 0:51:42)
# Exported lines 43000-43099 to steamspy_data.csv. Batch 430 time: 0:01:09 (avg: 0:01:11, remaining: 0:50:32)
# Exported lines 43100-43199 to steamspy_data.csv. Batch 431 time: 0:01:08 (avg: 0:01:11, remaining: 0:49:21)
# Exported lines 43200-43299 to steamspy_data.csv. Batch 432 time: 0:01:09 (avg: 0:01:10, remaining: 0:48:10)
# Exported lines 43300-43399 to steamspy_data.csv. Batch 433 time: 0:01:08 (avg: 0:01:10, remaining: 0:47:00)
# Exported lines 43400-43499 to steamspy_data.csv. Batch 434 time: 0:01:12 (avg: 0:01:10, remaining: 0:45:49)
# Exported lines 43500-43599 to steamspy_data.csv. Batch 435 time: 0:01:09 (avg: 0:01:10, remaining: 0:44:39)
# Exported lines 43600-43699 to steamspy_data.csv. Batch 436 time: 0:01:10 (avg: 0:01:10, remaining: 0:43:28)
# Exported lines 43700-43799 to steamspy_data.csv. Batch 437 time: 0:01:09 (avg: 0:01:10, remaining: 0:42:18)
# Exported lines 43800-43899 to steamspy_data.csv. Batch 438 time: 0:01:07 (avg: 0:01:10, remaining: 0:41:07)
# Exported lines 43900-43999 to steamspy_data.csv. Batch 439 time: 0:01:09 (avg: 0:01:10, remaining: 0:39:56)
# No response, waiting 10 seconds...
# Retrying. Attempt # 1
# Exported lines 44000-44099 to steamspy_data.csv. Batch 440 time: 0:02:09 (avg: 0:01:11, remaining: 0:38:50)
# Exported lines 44100-44199 to steamspy_data.csv. Batch 441 time: 0:01:09 (avg: 0:01:11, remaining: 0:37:39)
# Exported lines 44200-44299 to steamspy_data.csv. Batch 442 time: 0:01:09 (avg: 0:01:11, remaining: 0:36:29)
# Exported lines 44300-44399 to steamspy_data.csv. Batch 443 time: 0:01:09 (avg: 0:01:11, remaining: 0:35:18)
# Exported lines 44400-44499 to steamspy_data.csv. Batch 444 time: 0:01:08 (avg: 0:01:11, remaining: 0:34:07)
# Exported lines 44500-44599 to steamspy_data.csv. Batch 445 time: 0:01:08 (avg: 0:01:11, remaining: 0:32:56)
# Exported lines 44600-44699 to steamspy_data.csv. Batch 446 time: 0:01:08 (avg: 0:01:11, remaining: 0:31:46)
# Exported lines 44700-44799 to steamspy_data.csv. Batch 447 time: 0:01:08 (avg: 0:01:11, remaining: 0:30:35)
# Exported lines 44800-44899 to steamspy_data.csv. Batch 448 time: 0:01:08 (avg: 0:01:11, remaining: 0:29:24)
# Exported lines 44900-44999 to steamspy_data.csv. Batch 449 time: 0:01:09 (avg: 0:01:11, remaining: 0:28:14)
# Exported lines 45000-45099 to steamspy_data.csv. Batch 450 time: 0:01:09 (avg: 0:01:11, remaining: 0:27:03)
# Exported lines 45100-45199 to steamspy_data.csv. Batch 451 time: 0:01:09 (avg: 0:01:11, remaining: 0:25:52)
# Exported lines 45200-45299 to steamspy_data.csv. Batch 452 time: 0:01:08 (avg: 0:01:11, remaining: 0:24:42)
# Exported lines 45300-45399 to steamspy_data.csv. Batch 453 time: 0:01:08 (avg: 0:01:11, remaining: 0:23:31)
# Exported lines 45400-45499 to steamspy_data.csv. Batch 454 time: 0:01:13 (avg: 0:01:11, remaining: 0:22:21)
# Exported lines 45500-45599 to steamspy_data.csv. Batch 455 time: 0:01:11 (avg: 0:01:11, remaining: 0:21:10)
# Exported lines 45600-45699 to steamspy_data.csv. Batch 456 time: 0:01:08 (avg: 0:01:11, remaining: 0:19:59)
# Exported lines 45700-45799 to steamspy_data.csv. Batch 457 time: 0:01:09 (avg: 0:01:11, remaining: 0:18:49)
# Exported lines 45800-45899 to steamspy_data.csv. Batch 458 time: 0:01:08 (avg: 0:01:11, remaining: 0:17:38)
# Exported lines 45900-45999 to steamspy_data.csv. Batch 459 time: 0:01:08 (avg: 0:01:11, remaining: 0:16:27)
# Exported lines 46000-46099 to steamspy_data.csv. Batch 460 time: 0:01:08 (avg: 0:01:11, remaining: 0:15:17)
# Exported lines 46100-46199 to steamspy_data.csv. Batch 461 time: 0:01:09 (avg: 0:01:11, remaining: 0:14:06)
# Exported lines 46200-46299 to steamspy_data.csv. Batch 462 time: 0:01:09 (avg: 0:01:11, remaining: 0:12:56)
# Exported lines 46300-46399 to steamspy_data.csv. Batch 463 time: 0:01:08 (avg: 0:01:11, remaining: 0:11:45)
# Exported lines 46400-46499 to steamspy_data.csv. Batch 464 time: 0:01:08 (avg: 0:01:11, remaining: 0:10:35)
# Exported lines 46500-46599 to steamspy_data.csv. Batch 465 time: 0:01:08 (avg: 0:01:11, remaining: 0:09:24)
# Exported lines 46600-46699 to steamspy_data.csv. Batch 466 time: 0:01:08 (avg: 0:01:11, remaining: 0:08:14)
# Exported lines 46700-46799 to steamspy_data.csv. Batch 467 time: 0:01:09 (avg: 0:01:10, remaining: 0:07:03)
# Exported lines 46800-46899 to steamspy_data.csv. Batch 468 time: 0:01:08 (avg: 0:01:10, remaining: 0:05:52)
# Exported lines 46900-46999 to steamspy_data.csv. Batch 469 time: 0:01:08 (avg: 0:01:10, remaining: 0:04:42)
# Exported lines 47000-47099 to steamspy_data.csv. Batch 470 time: 0:01:08 (avg: 0:01:10, remaining: 0:03:31)
# Exported lines 47100-47199 to steamspy_data.csv. Batch 471 time: 0:01:07 (avg: 0:01:10, remaining: 0:02:21)
# Exported lines 47200-47299 to steamspy_data.csv. Batch 472 time: 0:01:08 (avg: 0:01:10, remaining: 0:01:10)
# Exported lines 47300-47397 to steamspy_data.csv. Batch 473 time: 0:01:06 (avg: 0:01:10, remaining: 0:00:00)
#
# Processing batches complete. 47397 apps written

# %%
df2 = pd.read_csv('../data/download/steamspy_data.csv')

# %%
df2['userscore']
# Out:
# 0      47353
# 100        4
# 95         3
# 46         2
# 68         2
# 94         2
# 84         2
# 51         2
# 69         2
# 70         2
# 80         2
# 76         1
# 96         1
# 65         1
# 97         1
# 67         1
# 71         1
# 73         1
# 74         1
# 61         1
# 77         1
# 92         1
# 63         1
# 81         1
# 82         1
# 53         1
# 55         1
# 87         1
# 88         1
# 59         1
# 60         1
# 78         1
# Name: userscore, dtype: int64

# %%
# inspect downloaded steamspy data
df2.set_index(['appid', 'name']).join(df.rename(columns={'steam_appid' : 'appid'}).set_index(['appid', 'name']), on= ['appid', 'name'], how='inner', lsuffix='spy', rsuffix='steam').head(1)
# Out:
#                      developer publisher  score_rank  positive  negative  \
# appid name
# 10    Counter-Strike     Valve     Valve         NaN    183324      4765
#
#                       userscore                    owners  average_forever  \
# appid name
# 10    Counter-Strike          0  10,000,000 .. 20,000,000            10560
#
#                       average_2weeks  median_forever  median_2weeks  price  \
# appid name
# 10    Counter-Strike             633             185           1007  999.0
#
#                       initialprice  discount  \
# appid name
# 10    Counter-Strike         999.0       0.0
#
#                                                               languages  \
# appid name
# 10    Counter-Strike  English, French, German, Italian, Spanish - Sp...
#
#                        genre    ccu  \
# appid name
# 10    Counter-Strike  Action  13403
#
#                                                                    tags  type  \
# appid name
# 10    Counter-Strike  {'Action': 5366, 'FPS': 4789, 'Multiplayer': 3...  game
#
#                       required_age is_free controller_support  dlc  \
# appid name
# 10    Counter-Strike           0.0   False                NaN  NaN
#
#                                                    detailed_description  \
# appid name
# 10    Counter-Strike  Play the world's number 1 online action game. ...
#
#                                                          about_the_game  \
# appid name
# 10    Counter-Strike  Play the world's number 1 online action game. ...
#
#                                                       short_description  \
# appid name
# 10    Counter-Strike  Play the world's number 1 online action game. ...
#
#                       fullgame  \
# appid name
# 10    Counter-Strike       NaN
#
#                                                     supported_languages  \
# appid name
# 10    Counter-Strike  English<strong>*</strong>, French<strong>*</st...
#
#                                                            header_image  \
# appid name
# 10    Counter-Strike  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                      website  \
# appid name
# 10    Counter-Strike     NaN
#
#                                                         pc_requirements  \
# appid name
# 10    Counter-Strike  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                                        mac_requirements  \
# appid name
# 10    Counter-Strike  {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
#
#                                                      linux_requirements  \
# appid name
# 10    Counter-Strike  {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...
#
#                      legal_notice drm_notice ext_user_account_notice  \
# appid name
# 10    Counter-Strike          NaN        NaN                     NaN
#
#                      developers publishers demos  \
# appid name
# 10    Counter-Strike  ['Valve']  ['Valve']   NaN
#
#                                                          price_overview  \
# appid name
# 10    Counter-Strike  {'currency': 'USD', 'initial': 999, 'final': 9...
#
#                          packages  \
# appid name
# 10    Counter-Strike  [574941, 7]
#
#                                                          package_groups  \
# appid name
# 10    Counter-Strike  [{'name': 'default', 'title': 'Buy Counter-Str...
#
#                                                           platforms  \
# appid name
# 10    Counter-Strike  {'windows': True, 'mac': True, 'linux': True}
#
#                                                              metacritic  \
# appid name
# 10    Counter-Strike  {'score': 88, 'url': 'https://www.metacritic.c...
#
#                      reviews  \
# appid name
# 10    Counter-Strike     NaN
#
#                                                              categories  \
# appid name
# 10    Counter-Strike  [{'id': 1, 'description': 'Multi-player'}, {'i...
#
#                                                       genres  \
# appid name
# 10    Counter-Strike  [{'id': '1', 'description': 'Action'}]
#
#                                                             screenshots  \
# appid name
# 10    Counter-Strike  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
#
#                      movies    recommendations achievements  \
# appid name
# 10    Counter-Strike    NaN  {'total': 110752}          NaN
#
#                                                        release_date  \
# appid name
# 10    Counter-Strike  {'coming_soon': False, 'date': 'Nov 1, 2000'}
#
#                                                            support_info  \
# appid name
# 10    Counter-Strike  {'url': 'http://steamcommunity.com/app/10', 'e...
#
#                                                              background  \
# appid name
# 10    Counter-Strike  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                                     content_descriptors
# appid name
# 10    Counter-Strike  {'ids': [2, 5], 'notes': 'Includes intense vio...

# %% [markdown]
# ## Next Steps
#
# Here we have defined and demonstrated the download process used to generate the data sets. This was completed separately but the full, raw data can be found [on Kaggle](https://kaggle.com/nikdavis/steam-store-raw).
#
# We now have two tables of data with a variety of information about apps on the Steam store. From the Steam data it looks like there are some useful columns like `required_age`, `developers` and `genres` which we can eventually turn into features for analysis, and a `price_overview` column which may inform the success and sales of each game. The `owners` column of the SteamSpy data could be useful, however the [margin of error](https://steamspy.com/about) means data may not be accurate enough for meaningful analysis, we'll have to see what we can manage after cleaning. Instead we may have to use the `positive` and `negative` ratings or average play-time to create our metrics. There is also a `tags` column which appears to crossover with the `categories` and `genres` columns in the Steam data. We may wish to merge these, or keep one over the other.
#
# These are all decisions we'll come to in later stages of the project. With the data downloaded, this stage is now complete. In the next step, we'll take care of preparing and cleaning the data, readying a complete data set to use for analysis.
