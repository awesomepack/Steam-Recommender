# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf


import pandas as pd 
application_df = pd.read_csv("../Steamdata.csv")
application_df.head()
# Out:
#    Unnamed: 0  type                       name  appid  required_age is_free  \
# 0           0  game             Counter-Strike     10           0.0   False
# 1           1  game      Team Fortress Classic     20           0.0   False
# 2           2  game              Day of Defeat     30           0.0   False
# 3           3  game         Deathmatch Classic     40           0.0   False
# 4           4  game  Half-Life: Opposing Force     50           0.0   False
#
#   controller_support  dlc                               detailed_description  \
# 0                NaN  NaN  Play the world's number 1 online action game. ...
# 1                NaN  NaN  One of the most popular online action games of...
# 2                NaN  NaN  Enlist in an intense brand of Axis vs. Allied ...
# 3                NaN  NaN  Enjoy fast-paced multiplayer gaming with Death...
# 4                NaN  NaN  Return to the Black Mesa Research Facility as ...
#
# ...

# %%
dftest = application_df

# %%
dftest.shape
# Out:
# (36150, 58)

# %%
dftest.isnull().sum()
# Out:
# Unnamed: 0                     0
# type                          95
# name                           5
# appid                          0
# required_age                  95
# is_free                       95
# controller_support         28177
# dlc                        29479
# detailed_description         124
# about_the_game               124
# short_description            122
# fullgame                   36150
# supported_languages          123
# header_image                  95
# website                    13210
# pc_requirements               95
# mac_requirements              95
# linux_requirements            95
# legal_notice               23806
# drm_notice                 35987
# ext_user_account_notice    35511
# developers                   218
# publishers                    95
# demos                      33202
# price_overview              5806
# packages                    5291
# package_groups                95
# platforms                     95
# ...

# %%
dftest = dftest.drop(['dlc','detailed_description','about_the_game','short_description','header_image','website','legal_notice','drm_notice','ext_user_account_notice','demos'], axis=1)
dftest.head()
# Out:
#    Unnamed: 0  type                       name  appid  required_age is_free  \
# 0           0  game             Counter-Strike     10           0.0   False
# 1           1  game      Team Fortress Classic     20           0.0   False
# 2           2  game              Day of Defeat     30           0.0   False
# 3           3  game         Deathmatch Classic     40           0.0   False
# 4           4  game  Half-Life: Opposing Force     50           0.0   False
#
#   controller_support  fullgame  \
# 0                NaN       NaN
# 1                NaN       NaN
# 2                NaN       NaN
# 3                NaN       NaN
# 4                NaN       NaN
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# ...

# %%
dftest.shape
# Out:
# (36150, 48)

# %%
dftest.isnull().sum()
# Out:
# Unnamed: 0                 0
# type                      95
# name                       5
# appid                      0
# required_age              95
# is_free                   95
# controller_support     28177
# fullgame               36150
# supported_languages      123
# pc_requirements           95
# mac_requirements          95
# linux_requirements        95
# developers               218
# publishers                95
# price_overview          5806
# packages                5291
# package_groups            95
# platforms                 95
# metacritic             32866
# reviews                29110
# categories               815
# genres                   170
# screenshots              149
# movies                  1946
# recommendations        26923
# achievements           15424
# release_date              95
# support_info              95
# background               147
# content_descriptors       95
# developer                206
# publisher                201
# ...

# %%
dftest = dftest.drop(['packages','package_groups','screenshots','movies'], axis=1)
dftest.head()
# Out:
#    Unnamed: 0  type                       name  appid  required_age is_free  \
# 0           0  game             Counter-Strike     10           0.0   False
# 1           1  game      Team Fortress Classic     20           0.0   False
# 2           2  game              Day of Defeat     30           0.0   False
# 3           3  game         Deathmatch Classic     40           0.0   False
# 4           4  game  Half-Life: Opposing Force     50           0.0   False
#
#   controller_support  fullgame  \
# 0                NaN       NaN
# 1                NaN       NaN
# 2                NaN       NaN
# 3                NaN       NaN
# 4                NaN       NaN
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# ...

# %%
dftest.isnull().sum()
# Out:
# Unnamed: 0                 0
# type                      95
# name                       5
# appid                      0
# required_age              95
# is_free                   95
# controller_support     28177
# fullgame               36150
# supported_languages      123
# pc_requirements           95
# mac_requirements          95
# linux_requirements        95
# developers               218
# publishers                95
# price_overview          5806
# platforms                 95
# metacritic             32866
# reviews                29110
# categories               815
# genres                   170
# recommendations        26923
# achievements           15424
# release_date              95
# support_info              95
# background               147
# content_descriptors       95
# developer                206
# publisher                201
# score_rank             36106
# positive                   0
# negative                   0
# userscore                  0
# ...

# %%
dftest = dftest.drop(['background','support_info','release_date','tags'], axis=1)
dftest.head()
# Out:
#    Unnamed: 0  type                       name  appid  required_age is_free  \
# 0           0  game             Counter-Strike     10           0.0   False
# 1           1  game      Team Fortress Classic     20           0.0   False
# 2           2  game              Day of Defeat     30           0.0   False
# 3           3  game         Deathmatch Classic     40           0.0   False
# 4           4  game  Half-Life: Opposing Force     50           0.0   False
#
#   controller_support  fullgame  \
# 0                NaN       NaN
# 1                NaN       NaN
# 2                NaN       NaN
# 3                NaN       NaN
# 4                NaN       NaN
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English, French, German, Italian, Spanish - Sp...
# 2  English, French, German, Italian, Spanish - Spain
# 3  English, French, German, Italian, Spanish - Sp...
# ...

# %%
dftest = dftest.drop(['fullgame'], axis=1)
dftest.head()
# Out:
#    Unnamed: 0  type                       name  appid  required_age is_free  \
# 0           0  game             Counter-Strike     10           0.0   False
# 1           1  game      Team Fortress Classic     20           0.0   False
# 2           2  game              Day of Defeat     30           0.0   False
# 3           3  game         Deathmatch Classic     40           0.0   False
# 4           4  game  Half-Life: Opposing Force     50           0.0   False
#
#   controller_support                                supported_languages  \
# 0                NaN  English<strong>*</strong>, French<strong>*</st...
# 1                NaN  English, French, German, Italian, Spanish - Sp...
# 2                NaN  English, French, German, Italian, Spanish - Spain
# 3                NaN  English, French, German, Italian, Spanish - Sp...
# 4                NaN                    English, French, German, Korean
#
#                                      pc_requirements  \
# ...

# %%
dftest.isnull().sum()
# Out:
# Unnamed: 0                 0
# type                      95
# name                       5
# appid                      0
# required_age              95
# is_free                   95
# controller_support     28177
# supported_languages      123
# pc_requirements           95
# mac_requirements          95
# linux_requirements        95
# developers               218
# publishers                95
# price_overview          5806
# platforms                 95
# metacritic             32866
# reviews                29110
# categories               815
# genres                   170
# recommendations        26923
# achievements           15424
# content_descriptors       95
# developer                206
# publisher                201
# score_rank             36106
# positive                   0
# negative                   0
# userscore                  0
# owners                     0
# average_forever            0
# average_2weeks             0
# median_forever             0
# ...

# %%
dftest = dftest.drop(['controller_support','supported_languages','pc_requirements','mac_requirements','linux_requirements'], axis=1)
dftest.head()
# Out:
#    Unnamed: 0  type                       name  appid  required_age is_free  \
# 0           0  game             Counter-Strike     10           0.0   False
# 1           1  game      Team Fortress Classic     20           0.0   False
# 2           2  game              Day of Defeat     30           0.0   False
# 3           3  game         Deathmatch Classic     40           0.0   False
# 4           4  game  Half-Life: Opposing Force     50           0.0   False
#
#              developers publishers  \
# 0             ['Valve']  ['Valve']
# 1             ['Valve']  ['Valve']
# 2             ['Valve']  ['Valve']
# 3             ['Valve']  ['Valve']
# 4  ['Gearbox Software']  ['Valve']
#
#                                       price_overview  \
# 0  {'currency': 'USD', 'initial': 999, 'final': 9...
# 1  {'currency': 'USD', 'initial': 499, 'final': 4...
# 2  {'currency': 'USD', 'initial': 499, 'final': 4...
# 3  {'currency': 'USD', 'initial': 499, 'final': 4...
# ...

# %%
dftest = dftest.drop(['content_descriptors'], axis=1)
dftest.head()
# Out:
#    Unnamed: 0  type                       name  appid  required_age is_free  \
# 0           0  game             Counter-Strike     10           0.0   False
# 1           1  game      Team Fortress Classic     20           0.0   False
# 2           2  game              Day of Defeat     30           0.0   False
# 3           3  game         Deathmatch Classic     40           0.0   False
# 4           4  game  Half-Life: Opposing Force     50           0.0   False
#
#              developers publishers  \
# 0             ['Valve']  ['Valve']
# 1             ['Valve']  ['Valve']
# 2             ['Valve']  ['Valve']
# 3             ['Valve']  ['Valve']
# 4  ['Gearbox Software']  ['Valve']
#
#                                       price_overview  \
# 0  {'currency': 'USD', 'initial': 999, 'final': 9...
# 1  {'currency': 'USD', 'initial': 499, 'final': 4...
# 2  {'currency': 'USD', 'initial': 499, 'final': 4...
# 3  {'currency': 'USD', 'initial': 499, 'final': 4...
# ...

# %%
# dummiestest = pd.get_dummies(dftest, columns=['name','appid','required_age','is_free','developers','publishers','price_overview',         
# 'platforms','categories','genres','recommendations','achievements','developer','publisher','score_rank','positive','negative','userscore','owners','average_forever',
# 'average_2weeks','median_forever','median_2weeks','price','initialprice','discount','languages','genre','ccu'], drop_first=True, dtype=float)
# dummiestest.shape
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-be8eab3efea4> in <module>
#       1 dummiestest = pd.get_dummies(dftest, columns=['name','appid','required_age','is_free','developers','publishers','price_overview',
#       2 'platforms','categories','genres','recommendations','achievements','developer','publisher','score_rank','positive','negative','userscore','owners','average_forever',
# ----> 3 'average_2weeks','median_forever','median_2weeks','price','initialprice','discount','languages','genre','ccu'], drop_first=True, dtype=float)
#       4 dummiestest.shape
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     923             )
#     924             with_dummies.append(dummy)
# --> 925         result = concat(with_dummies, axis=1)
# ...

# %%
dummiestestx = dummiestest.drop('', axis=1)
dummiestestx.head()
